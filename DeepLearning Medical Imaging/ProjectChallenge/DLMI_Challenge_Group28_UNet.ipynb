# %% [markdown]
# # Deep Learning for Medical Imaging - Challenge - Group 28
#
# ## ResNet model
#
# ### Elycheva Dray, Théo Di Piazza
#
# This notebook contains the challenge code for the **ResNet** model. If you want the code for the U-Net model: **DLMI_Challenge_Group28_UNet.ipynb**

# %% [markdown]
# # Download data
#
# The first step is to download the challenge data available on Github.

# %%
# remove data if needed
import os
import shutil

if(os.path.exists(('/content/MVA-Dose-Prediction'))):
  shutil.rmtree('/content/MVA-Dose-Prediction')

# %%
# clone the github with datas
# !git clone https://github.com/soniamartinot/MVA-Dose-Prediction.git
# Out:
# Cloning into 'MVA-Dose-Prediction'...
# remote: Enumerating objects: 38724, done.
# remote: Total 38724 (delta 0), reused 0 (delta 0), pack-reused 38724
# Receiving objects: 100% (38724/38724), 77.02 MiB | 14.16 MiB/s, done.
# Resolving deltas: 100% (30603/30603), done.
# Updating files: 100% (39600/39600), done.

# %% [markdown]
# # Setup, libraries
#
# Then you have to install the necessary libraries to execute the code.

# %%
# Libraries
import os
import cv2
import time
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from torch.utils.data import Dataset
from torch.optim.lr_scheduler import StepLR

# %% [markdown]
# # Data Visualization
#
# Data discovery is an important step in a Computer Vision project. It helps to understand the context and visualising a few samples helps to see if pre-processing or data augmentation steps can be useful.

# %%
# Display scanner - dose - possible_dose_mask
path_data = '/content/MVA-Dose-Prediction'
path_train = os.path.join(path_data, 'train')

samples_id = [0, 100, 1000] # samples to display
figure_name = ['ct', 'dose', 'possible_dose_mask'] # figures to display

# iterate over samples to display
for sample_id in samples_id:

  f, axes = plt.subplots(1, 3, figsize=(10, 4))
  patient_folder = os.path.join(path_train, 'sample_{sample_id}'.format(sample_id=sample_id))

  # display each figure
  for i, figure in enumerate(figure_name):
    path_file = os.path.join(patient_folder, '{figure}.npy'.format(figure=figure))
    img = np.load(path_file)
    axes[i].set_title(figure)
    axes[i].imshow(img)

  plt.suptitle('Patient {sample_id}'.format(sample_id=sample_id))
  plt.show()

# %%
# Display structure masks
path_data = '/content/MVA-Dose-Prediction'
path_train = os.path.join(path_data, 'train')

samples_id = [0, 100, 1000]

for sample_id in samples_id:

  f, axes = plt.subplots(1, 10, figsize=(22, 3))
  patient_folder = os.path.join(path_train, 'sample_{sample_id}'.format(sample_id=sample_id))
  path_file = os.path.join(patient_folder, 'structure_masks.npy')
  structure_masks = np.load(path_file)

  for i in range(10):
    img = structure_masks[i]
    axes[i].set_title('{i}'.format(i=i))
    axes[i].axis('off')
    axes[i].imshow(img)

  plt.suptitle('Structure masks for patient {sample_id}'.format(sample_id=sample_id))
  plt.show()

# %% [markdown]
# # Pre-processing
#
# Patients without possible dose mask will be removed from the train and test set. It is assumed that these data do not provide any useful information for training or evaluating the model.

# %%
# remove patient with null dose prediction
# load dataset
path_data = '/content/MVA-Dose-Prediction'
path_train = os.path.join(path_data, 'train')
path_val = os.path.join(path_data, 'validation')
path_test = os.path.join(path_data, 'test')

files_patern = ['ct', 'dose', 'possible_dose_mask', 'structure_masks']

# remove train sample
count_train_remove = 0
for sample_id_name in os.listdir(path_train):
    path_sample = os.path.join(path_train, sample_id_name)
    dose = np.load(os.path.join(path_sample, files_patern[1] + '.npy'))
    dose = dose.astype(np.float32)
    if(np.sum(dose)==0):
      count_train_remove += 1
      shutil.rmtree(path_sample)

# remove val sample
count_val_remove = 0
for sample_id_name in os.listdir(path_val):
    path_sample = os.path.join(path_val, sample_id_name)
    dose = np.load(os.path.join(path_sample, files_patern[1] + '.npy'))
    dose = dose.astype(np.float32)
    if(np.sum(dose)==0):
      count_val_remove += 1
      shutil.rmtree(path_sample)

print(f'Number of elements removed from train set : {count_train_remove}')
print(f'Number of elements removed from train set : {count_val_remove}')
# Out:
# Number of elements removed from train set : 271
# Number of elements removed from train set : 54

# %% [markdown]
# # Load data
#
# From now on, it is a question of loading the data via the dataset and dataloader classes of the PyTorch library. For this, we define a class capable of reading, loading and iterating on the train and test data.

# %%
# CustomDataset class
class CustomDataset(Dataset):
    '''
    Custom dataset
    '''

    def __init__(self, data_path, files_patern = ['ct', 'dose', 'possible_dose_mask', 'structure_masks'], transform=None, set_name='train'):
        super(CustomDataset, self).__init__()

        self.transform = transform
        self.data_path = data_path # path of train, test or val folder
        self.sample_list = os.listdir(data_path) # list of samples
        self.files_patern = files_patern # files patern name
        self.set_name = set_name # train, val or test

    def __len__(self):
        return len(self.sample_list)

    def __getitem__(self, idx):
        '''
        Get data for patient given idx
        '''
        # get path of sample to load
        sample_path = os.path.join(self.data_path, self.sample_list[idx])

        # load files for the given patient
        ct = np.load(os.path.join(sample_path, self.files_patern[0] + '.npy'))
        possible_dose_mask = np.load(os.path.join(sample_path, self.files_patern[2] + '.npy'))
        structure_masks = np.load(os.path.join(sample_path, self.files_patern[3] + '.npy'))
        # load dose only for train and val set
        if(self.set_name == 'train' or self.set_name=='val'):
          dose = np.load(os.path.join(sample_path, self.files_patern[1] + '.npy'))
          dose = dose.astype(np.float32)
        else:
          dose = self.sample_list[idx] # return sample_id for test predictions

        # concatenate all data
        data = np.concatenate([ct[np.newaxis, :, :], possible_dose_mask[np.newaxis, :, :], structure_masks], axis=0)
        data = data.astype(np.float32)

        return data, dose

# %%
## load dataset, dataloader

# load dataset
path_data = '/content/MVA-Dose-Prediction'
path_train = os.path.join(path_data, 'train')
path_val = os.path.join(path_data, 'validation')
path_test = os.path.join(path_data, 'test')

dataset_train = CustomDataset(path_train, set_name='train')
dataset_val = CustomDataset(path_val, set_name='val')
dataset_test = CustomDataset(path_test, set_name='test')

print(f'Train set successfully loaded with {len(dataset_train)} elements!')
print(f'Validation set successfully loaded with {len(dataset_val)} elements!')
print(f'Test set successfully loaded with {len(dataset_test)} elements!')

# load dataloader
torch.manual_seed(42) # fix seed to have same laoder when shuffle
batch_size = 64
loader_train = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
loader_val = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=True)
loader_test = torch.utils.data.DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

print(f'\nTrain, Validation and Test loaders successfully loaded with batch size = {batch_size}')
# Out:
# Train set successfully loaded with 7800 elements!
# Validation set successfully loaded with 1200 elements!
# Test set successfully loaded with 1200 elements!
#
# Train, Validation and Test loaders successfully loaded with batch size = 64

# %% [markdown]
# # Data Augmentation
#
# If required, a data augmentation step can be used to increase the size of the training dataset by adding modified samples via transformations from the initial train set. The following transformations are used : flip, rotation around y axis and translation. These classical transformations are taken from other projects and computer vision work for the medical field.

# %%
# flip_img
def flip_img(data):
  '''
  perform flip of 3D image img
  '''
  for idx in range(len(data)):
    data[idx] = data[idx][:, ::-1]

  return data

# %%
# rotation_img
def rotation_img(data):
  '''
    Perform a rotation over z of a random angle
  '''

  # angles, boder value
  list_angles=(0, 40, 80, 120, 160, 200, 240, 280, 320)
  _angle = random.sample(list_angles, 1)[0]
  list_boder_value=(0, 0, 0)

  # images shape, angle rotation and scaling transformation
  rows, cols = data[0].shape
  _scale = 1.

  # perform transformation
  M = cv2.getRotationMatrix2D(((cols - 1) / 2.0, (rows - 1) / 2.0), _angle, scale=_scale)
  for idx in range(len(data)):
    data[idx] = \
      cv2.warpAffine(data[idx],
                      M,
                      (cols, rows),
                      borderMode=cv2.BORDER_CONSTANT,
                      borderValue=list_boder_value)
    
  return data

# %%
# translate_img
def translate_img(data):
  '''
  perform random translation over image img with the mask roi_mask of possible dose
  '''
  roi_mask = data[1] # 1 is index of possible_dose_mask
  # if no possible dose mask, no augmentation possible
  if(np.sum(roi_mask) == 0):
    return data
  
  else:
    # parameters translation
    max_shift=20
    exist_mask = np.where(roi_mask > 0)
    ori_z = data[0].shape[1:][0]
    bz = min(max_shift - 1, np.min(exist_mask[0]))
    ez = max(ori_z - 1 - max_shift, np.max(exist_mask[0]))

    data_crop = []
    # crop area of interest
    for idx in range(len(data)):
      data_crop.append(data[idx][:, bz:ez + 1])
    data = np.array(data_crop)

    # padding to perform translation
    _, ori_z  = data[0].shape[:]
    new_z = 128
    pad_z = new_z - ori_z
    pad_z_1 = random.randint(0, pad_z)
    pad_z_2 = pad_z - pad_z_1

    new_data = []
    for idx in range(len(data)):
      new_data.append(np.pad(data[idx], ((0, 0), (pad_z_1, pad_z_2)),
                                mode='constant',
                                constant_values=[0, 0]))
    data = np.array(new_data)
  
  return data

# %% [markdown]
# Once the 3 transformations are applied, we define **transform_data** which allows us to apply the 3 successive transformations to input data.

# %%
# transorm_data
def transform_data(data):
  '''
  perform flip, rotate and translation over data
  '''
  p_flip, p_rotate, p_translate = 0.8, 0.4, 0.8

  # flip
  if(random.random() < p_flip):
    data = flip_3d(data)

  # rotate
  if(random.random() < p_rotate):
    data = rotate_arnd_z(data)

  # translation
  if(random.random() < p_translate):
    data = random_translate(data)

  return data

# %% [markdown]
# Finally, we define **perform_data_aug** which applies the data augmentation to the input data. As a parameter, the **percentage_aug** argument is used to select the percentage of trainset data that will be augmented.

# %%
# perform_data_aug
def perform_data_aug(pourcentage_aug=10):
  '''
  perform data augmentation over pourcentage_aug% of the train set
  directly modifies train files, return None
  '''

  # path to the train set
  path_train = '/content/MVA-Dose-Prediction/train'

  # start by removing augmented sample in case of multiple call of perform_data_aug
  for sample_id in os.listdir(path_train):
    if('aug' in sample_id):
      path_sample_aug = os.path.join(path_train, sample_id)
      shutil.rmtree(path_sample_aug)

  start_nb_samples = len(os.listdir(path_train))
  print(f'Starting Data Augmentation !')

  # names of files
  files_patern = ['ct', 'dose', 'possible_dose_mask', 'structure_masks']

  max_aug = (pourcentage_aug/100)*len(os.listdir(path_train)) # max number of augmentation
  nb_aug = 0 # number of sample augmented

  # iterate over sample
  start_time = time.time()
  for sample_id in os.listdir(path_train):
    
    # path sample
    path_sample = os.path.join(path_train, sample_id)
    
    # load files for the given patient
    ct = np.load(os.path.join(path_sample, files_patern[0] + '.npy'))
    possible_dose_mask = np.load(os.path.join(path_sample, files_patern[2] + '.npy'))
    structure_masks = np.load(os.path.join(path_sample, files_patern[3] + '.npy'))
    dose = np.load(os.path.join(path_sample, files_patern[1] + '.npy'))
    dose = dose.astype(np.float32)

    # concatenate data
    data = np.concatenate([ct[np.newaxis, :, :], possible_dose_mask[np.newaxis, :, :], 
                          dose[np.newaxis, :, :], structure_masks], axis=0)
    data = data.astype(np.float32)

    # perform data augmentation
    if(nb_aug < max_aug):
      nb_aug += 1
      # 2 data augmentation for each sample
      for i in range(1):
        # new id for augmented sample
        sample_id_aug = sample_id + 'aug' + str(i)
        # perform data augmentation
        data_aug = transform_data(data)
        ct = data_aug[0]
        possible_dose_mask = data_aug[1]
        dose = data_aug[2]
        structure_masks = data_aug[3:]
        # save files
        path_sample_aug = os.path.join(path_train, sample_id_aug)
        # if repository exists, remove it
        if os.path.exists(path_sample_aug):
          shutil.rmtree(path_sample_aug)
        os.mkdir(path_sample_aug)

        np.save(os.path.join(path_sample_aug, 'ct.npy'), ct)
        np.save(os.path.join(path_sample_aug, 'dose.npy'), dose)
        np.save(os.path.join(path_sample_aug, 'possible_dose_mask.npy'), possible_dose_mask)
        np.save(os.path.join(path_sample_aug, 'structure_masks.npy'), structure_masks)

  end_time = time.time() - start_time
  end_nb_samples = len(os.listdir(path_train))
  print(f'Data Augmentation successfully done !')
  print(f'> Initial number of samples : {start_nb_samples}')
  print(f'> Final number of samples : {end_nb_samples}')
  print(f'> + {end_nb_samples - start_nb_samples} augmented samples !')
  print(f'> Execution times : {end_time:.2f}s !')

  return

# %%
# perform data augmentation on train set
perform_data_aug(100)
# Out:
# Starting Data Augmentation !
# Data Augmentation successfully done !
# > Initial number of samples : 7529
# > Final number of samples : 15058
# > + 7529 augmented samples !
# > Execution times : 134.15s !

# %% [markdown]
# Once the data has been augmented, it is now time to reload the data coders with augmented images!

# %%
# reload dataloaders with augmented
## load dataset, dataloader

# load dataset
path_data = '/content/MVA-Dose-Prediction'
path_train = os.path.join(path_data, 'train')
path_val = os.path.join(path_data, 'validation')
path_test = os.path.join(path_data, 'test')

dataset_train = CustomDataset(path_train, set_name='train')
dataset_val = CustomDataset(path_val, set_name='val')
dataset_test = CustomDataset(path_test, set_name='test')

print(f'Train set successfully loaded with {len(dataset_train)} elements!')
print(f'Validation set successfully loaded with {len(dataset_val)} elements!')
print(f'Test set successfully loaded with {len(dataset_test)} elements!')

# load dataloader
torch.manual_seed(42) # fix seed to have same laoder when shuffle
batch_size = 64
loader_train = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
loader_val = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=True)
loader_test = torch.utils.data.DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

print(f'\nTrain, Validation and Test loaders successfully loaded with batch size = {batch_size}')
# Out:
# Train set successfully loaded with 15058 elements!
# Validation set successfully loaded with 1146 elements!
# Test set successfully loaded with 1200 elements!
#
# Train, Validation and Test loaders successfully loaded with batch size = 64

# %% [markdown]
# # Training
#
# Now it is a matter of training the model.

# %%
# Libraries
import os
import time
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from torch.utils.data import Dataset
from torch.optim.lr_scheduler import StepLR, MultiStepLR

# %% [markdown]
# Below are implemented **train_step** and **get_lr** which allow to train the model for a given epoch et to return the learning rate of the model at a given time.

# %%
#@title utils functions to train
def train_step(loader, model, criterion, optimizer, epoch):

  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  epoch_loss_sum = []
  predictions, labels = [], []

  for i, (data, label) in enumerate(loader, 1):

    data, label = data.to(device), label.to(device)

    prediction = model(data)
    loss = criterion(prediction, label.view(prediction.shape))

    if model.training:
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    epoch_loss_sum += [loss.item()]
    predictions += [0]# [prediction]
    labels += [0]#[label]

    if((i+1)%25==0):
      print('Step {i}/{n} - mean loss : {epoch_loss_current}'.format(i=i+1, n=len(loader), epoch_loss_current=np.mean(epoch_loss_sum)))

  return np.mean(epoch_loss_sum), prediction, labels

# get_lr function
def get_lr(optimizer):
    '''
    returns learning rate for the optimizer
    '''
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %% [markdown]
# ## Model
#
# Then, it is time to implement the ResNet model. As ResNet is widely used in computer vision, we used a version of the model available on github and we change some parameters according to our needs, i.e. input/output dimensions, number of layers, etc...
#
# This is based on the implementation used for TP5 DLMI.

# %%
# Model UNet
def get_activation(activation_type):
    activation_type = activation_type.lower()
    if hasattr(nn, activation_type):  return getattr(nn, activation_type)()
    else:  return nn.ReLU()

class ConvBatchNorm(nn.Module):
    """This block implements the sequence: (convolution => [BN] => ReLU)"""  
    def __init__(self, in_channels, out_channels, activation='ReLU'):
        super(ConvBatchNorm, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, 
                              kernel_size=3, padding=1)
        self.norm = nn.BatchNorm2d(out_channels)
        self.activation = get_activation(activation)
      
    def forward(self, x):
        out = self.conv(x)
        out = self.norm(out)
        return self.activation(out)

def _make_nConv(in_channels, out_channels, nb_Conv, activation='ReLU'):
    layers = []
    layers.append(ConvBatchNorm(in_channels, out_channels, activation))
    for _ in range(nb_Conv-1):
        layers.append(ConvBatchNorm(out_channels, out_channels, activation))
    return nn.Sequential(*layers)

class DownBlock(nn.Module):
    """Downscaling with maxpooling and convolutions"""
    def __init__(self, in_channels, out_channels, nb_Conv, activation='ReLU'):
        super(DownBlock, self).__init__()
        self.maxpool = nn.MaxPool2d(2)
        self.nConvs = _make_nConv(in_channels, out_channels, nb_Conv, activation)

    def forward(self, x):
        out = self.maxpool(x)
        return self.nConvs(out)  

class Bottleneck(nn.Module):
    def __init__(self, in_channels, out_channels, nb_Conv=2, activation='ReLU'):
        super(Bottleneck, self).__init__()
        self.nConvs = _make_nConv(in_channels, out_channels, nb_Conv, activation)
        self.last = nn.ConvTranspose2d(out_channels, in_channels, 
                                           kernel_size=3, stride=2, 
                                           padding=1, output_padding=1)
    def forward(self, input):
        out = self.nConvs(input)
        #   out = self.last(out)
        return out

class UpBlock(nn.Module):
    """Upscaling then conv"""
    def __init__(self, in_channels, out_channels, nb_Conv=2, activation='ReLU'):
        super(UpBlock, self).__init__()        
        self.up = nn.Upsample(scale_factor=2)
        self.nConvs = _make_nConv(in_channels, out_channels, nb_Conv, activation)

    def forward(self, x, skip_x):
        out = self.up(x)
        x = torch.cat([out, skip_x], dim=1) # dim 1 is the channel dimension
        return self.nConvs(x)

class UNet(nn.Module):
    def __init__(self, n_input_channels=12, n_output_channels=1):
        '''
        n_channels : number of channels of the input. 
                        By default 12, because we have 10 masks, 1 possible dose and 1 scanner.
        n_labels : number of channels of the ouput.
                      By default 1 
        '''
        super(UNet, self).__init__()
        self.n_channels = n_input_channels
        self.n_classes = n_output_channels

        # Question here
        self.inc = ConvBatchNorm(self.n_channels, 64)
        self.down1 = DownBlock(64, 128, nb_Conv=2)
        self.down2 = DownBlock(128, 256, nb_Conv=2)
        self.down3 = DownBlock(256, 512, nb_Conv=2)
        self.down4 = DownBlock(512, 512, nb_Conv=2)

        self.Encoder = [self.down1, self.down2, self.down3, self.down4]

        self.bottleneck = Bottleneck(512, 512)

        self.up1 = UpBlock(1024, 256, nb_Conv=2)
        self.up2 = UpBlock(512, 128, nb_Conv=2)
        self.up3 = UpBlock(256, 64, nb_Conv=2)
        # self.up4 = UpBlock(128, 64, nb_Conv=2)

        self.Decoder = [self.up1, self.up2, self.up3]

        self.outc = nn.Sequential(nn.ConvTranspose2d(64, 64, 
                                                     kernel_size=3, stride=2, 
                                                     padding=1, output_padding=1),
                                  nn.Conv2d(64, self.n_classes, kernel_size=3, stride=1, padding=1)
                                  )
        #self.last_activation = get_activation('ReLU')
        self.last_activation = get_activation('Softmax')

    
    def forward(self, x):
        # Forward 
        skip_inputs = []
        x = self.inc(x) 

        # Forward through encoder
        for i, block in enumerate(self.Encoder):
            x = block(x)  
            print(f'encoder {i} : {x.shape}')
            skip_inputs += [x] 
#             print(x.shape)             

        # We are at the bottleneck.
        bottleneck = self.bottleneck(x)
        print(f'bottleneck : {bottleneck.shape}')

        # Forward through decoder
        skip_inputs.reverse()

        decoded = bottleneck
        for i, block in enumerate(self.Decoder):
            # Concat with skipconnections
            skipped = skip_inputs[i+1]
#             print(skipped.shape, decoded.shape)
            decoded = block(decoded, skipped)
            print(f'decoder {i} : {decoder.shape}')

        out = self.last_activation(self.outc(decoded))
        print(f'output : {out.shape}')
        return out

# %% [markdown]
# Once the model is implemented, it is time to initialize it with optimizer, scheduler, loss function and some parameters.

# %%
# initialize model, optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = UNet(n_input_channels=12, n_output_channels=1)
model = model.to(device)

criterion = nn.L1Loss() # loss
learning_rate = 0.0001 # optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
#scheduler = StepLR(optimizer, step_size=3, gamma=0.1) # scheduler
scheduler = MultiStepLR(optimizer, milestones=[10, 15, 25], gamma=0.1) # scheduler

# %% [markdown]
# Then, we can start training.

# %%
# start training
start = time.time()
epochs = 30

losses_train, losses_val = [], [] # stock losses train, validation

for epoch in range(epochs): 
  print('******** Epoch [{}/{}]  ********'.format(epoch+1, epochs))
  print(f'Learning rate : {get_lr(optimizer)}')

  model.train() # training
  epoch_loss, _, _ = train_step(loader_train, model, criterion, optimizer, epoch)
  losses_train += [epoch_loss]
  print('> Training Loss : {epoch_loss}!'.format(epoch_loss=epoch_loss))

  with torch.no_grad(): # validation
    model.eval() 
    epoch_loss, _, _ = train_step(loader_val, model, criterion, optimizer, epoch)
    losses_val += [epoch_loss]
    print('> Validation Loss : {epoch_loss}!\n'.format(epoch_loss=epoch_loss))

  scheduler.step() # scheduler step

end = time.time()
exec_time = end - start
print(f'\n> Execution time : {exec_time:.2f}s')
# Out:
# ******** Epoch [1/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 2.835926800966263
# Step 50/122 - mean loss : 2.652569308572886
# Step 75/122 - mean loss : 2.426738991930678
# Step 100/122 - mean loss : 2.1474978117027668
# > Training Loss : 1.9429373750921155!
# > Validation Loss : 0.9860987506414715!
#
# ******** Epoch [2/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.9575789744655291
# Step 50/122 - mean loss : 0.9481884411403111
# Step 75/122 - mean loss : 0.9428682254778372
# Step 100/122 - mean loss : 0.9214401889329005
# > Training Loss : 0.9087166439314358!
# > Validation Loss : 1.5040036565379094!
#
# ******** Epoch [3/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.8127445379892985
# Step 50/122 - mean loss : 0.80512529125019
# Step 75/122 - mean loss : 0.8036466023406467
# Step 100/122 - mean loss : 0.8005609927755414
# > Training Loss : 0.8008208421410107!
# > Validation Loss : 0.9234590028461657!
#
# ******** Epoch [4/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.7647305950522423
# Step 50/122 - mean loss : 0.7414306681983325
# Step 75/122 - mean loss : 0.7429736369364971
# Step 100/122 - mean loss : 0.7392154239644908
# > Training Loss : 0.733524647403936!
# > Validation Loss : 0.8513586395665219!
#
# ******** Epoch [5/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.6871604571739832
# Step 50/122 - mean loss : 0.6811001179169636
# Step 75/122 - mean loss : 0.6801392033293441
# Step 100/122 - mean loss : 0.675080246997602
# > Training Loss : 0.6721048941377734!
# > Validation Loss : 0.9640791918102064!
#
# ******** Epoch [6/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.6421723067760468
# Step 50/122 - mean loss : 0.6350479332768187
# Step 75/122 - mean loss : 0.6351330151429048
# Step 100/122 - mean loss : 0.6343807451652758
# > Training Loss : 0.628944528884575!
# > Validation Loss : 0.9518967647301523!
#
# ******** Epoch [7/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.6130169952909151
# Step 50/122 - mean loss : 0.6056880038611743
# Step 75/122 - mean loss : 0.5947151707636343
# Step 100/122 - mean loss : 0.5919948388831784
# > Training Loss : 0.586584165448048!
# > Validation Loss : 0.9679853602459556!
#
# ******** Epoch [8/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.5384839462737242
# Step 50/122 - mean loss : 0.5399684638393168
# Step 75/122 - mean loss : 0.5454977859516401
# Step 100/122 - mean loss : 0.5425548541425455
# > Training Loss : 0.5398620064141321!
# > Validation Loss : 0.9362770224872389!
#
# ******** Epoch [9/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.5107630404333273
# Step 50/122 - mean loss : 0.5117672693972685
# Step 75/122 - mean loss : 0.51193532629593
# Step 100/122 - mean loss : 0.511220410616711
# > Training Loss : 0.5136022042544162!
# > Validation Loss : 1.149779802874515!
#
# ******** Epoch [10/30]  ********
# Learning rate : 0.0001
# Step 25/122 - mean loss : 0.48768505826592445
# Step 50/122 - mean loss : 0.4825771329354267
# Step 75/122 - mean loss : 0.48197343623315964
# Step 100/122 - mean loss : 0.48197945199831566
# > Training Loss : 0.48019012051527615!
# > Validation Loss : 0.7144660196806255!
#
# ******** Epoch [11/30]  ********
# Learning rate : 1e-05
# Step 25/122 - mean loss : 0.4497415708998839
# Step 50/122 - mean loss : 0.444011813523818
# Step 75/122 - mean loss : 0.4348151413975535
# Step 100/122 - mean loss : 0.43498023892893933
# > Training Loss : 0.43344632157536805!
# > Validation Loss : 0.6889591217041016!
#
# ******** Epoch [12/30]  ********
# Learning rate : 1e-05
# Step 25/122 - mean loss : 0.409786952038606
# Step 50/122 - mean loss : 0.40930814645728286
# Step 75/122 - mean loss : 0.4099473413583395
# Step 100/122 - mean loss : 0.40834070727078603
# > Training Loss : 0.408183644296693!
# > Validation Loss : 0.6873479077690526!
#
# ******** Epoch [13/30]  ********
# Learning rate : 1e-05
# Step 25/122 - mean loss : 0.40673403938611347
# Step 50/122 - mean loss : 0.40500728329833674
# Step 75/122 - mean loss : 0.4036792782512871
# Step 100/122 - mean loss : 0.403167418458245
# > Training Loss : 0.4028296331401731!
# > Validation Loss : 0.6996739349867168!
#
# ******** Epoch [14/30]  ********
# Learning rate : 1e-05
# Step 25/122 - mean loss : 0.39411376044154167
# Step 50/122 - mean loss : 0.3941042842913647
# Step 75/122 - mean loss : 0.3920831337973878
# Step 100/122 - mean loss : 0.3945940760048953
# > Training Loss : 0.39395619000567766!
# > Validation Loss : 0.699311309739163!
#
# ******** Epoch [15/30]  ********
# Learning rate : 1e-05
# Step 25/122 - mean loss : 0.3918113211790721
# Step 50/122 - mean loss : 0.38873203372468756
# Step 75/122 - mean loss : 0.38730699589123596
# Step 100/122 - mean loss : 0.38631876038782526
# > Training Loss : 0.3856314897048669!
# > Validation Loss : 0.6884513748319525!
#
# ******** Epoch [16/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.3697509194413821
# Step 50/122 - mean loss : 0.38120340996859026
# Step 75/122 - mean loss : 0.383062855214686
# Step 100/122 - mean loss : 0.3789799866652248
# > Training Loss : 0.3779027278794617!
# > Validation Loss : 0.6893948693024484!
#
# ******** Epoch [17/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.37673500056068104
# Step 50/122 - mean loss : 0.3721504606762711
# Step 75/122 - mean loss : 0.3739224591770688
# Step 100/122 - mean loss : 0.37444157070583767
# > Training Loss : 0.37346425628075836!
# > Validation Loss : 0.6890210760267157!
#
# ******** Epoch [18/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.37110679348309833
# Step 50/122 - mean loss : 0.3746454691400333
# Step 75/122 - mean loss : 0.37416694776431936
# Step 100/122 - mean loss : 0.37748741561716254
# > Training Loss : 0.37586740807431646!
# > Validation Loss : 0.6887986063957214!
#
# ******** Epoch [19/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.36250829820831615
# Step 50/122 - mean loss : 0.36822235401795833
# Step 75/122 - mean loss : 0.37076290958636515
# Step 100/122 - mean loss : 0.37191162988392995
# > Training Loss : 0.3729835741344045!
# > Validation Loss : 0.6902445084170291!
#
# ******** Epoch [20/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.36975816761453945
# Step 50/122 - mean loss : 0.3746492315311821
# Step 75/122 - mean loss : 0.37253362423664815
# Step 100/122 - mean loss : 0.3693595802543139
# > Training Loss : 0.3698641027583451!
# > Validation Loss : 0.6905476011727986!
#
# ******** Epoch [21/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.3659934339423974
# Step 50/122 - mean loss : 0.36674033865636707
# Step 75/122 - mean loss : 0.3711969264455744
# Step 100/122 - mean loss : 0.37140698174033504
# > Training Loss : 0.3720404232134584!
# > Validation Loss : 0.6919385006553248!
#
# ******** Epoch [22/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.3790488826731841
# Step 50/122 - mean loss : 0.3761750544820513
# Step 75/122 - mean loss : 0.37380517294278015
# Step 100/122 - mean loss : 0.3695904260331934
# > Training Loss : 0.370476882721557!
# > Validation Loss : 0.6876131892204285!
#
# ******** Epoch [23/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.37487299740314484
# Step 50/122 - mean loss : 0.37150154430039073
# Step 75/122 - mean loss : 0.3697646783815848
# Step 100/122 - mean loss : 0.3690772092703617
# > Training Loss : 0.36964102211545724!
# > Validation Loss : 0.6915869242266605!
#
# ******** Epoch [24/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.35768505558371544
# Step 50/122 - mean loss : 0.3599794786803576
# Step 75/122 - mean loss : 0.3634953027641451
# Step 100/122 - mean loss : 0.3634674338379292
# > Training Loss : 0.36923258079857124!
# > Validation Loss : 0.6898876083524603!
#
# ******** Epoch [25/30]  ********
# Learning rate : 1.0000000000000002e-06
# Step 25/122 - mean loss : 0.3746034341553847
# Step 50/122 - mean loss : 0.36905259198072005
# Step 75/122 - mean loss : 0.37250501078528325
# Step 100/122 - mean loss : 0.37085139661124256
# > Training Loss : 0.3689698462114959!
# > Validation Loss : 0.6899304672291404!
#
# ******** Epoch [26/30]  ********
# Learning rate : 1.0000000000000002e-07
# Step 25/122 - mean loss : 0.3641157920161883
# Step 50/122 - mean loss : 0.3709836358926734
# Step 75/122 - mean loss : 0.3658717935149734
# Step 100/122 - mean loss : 0.36386912248351355
# > Training Loss : 0.3644831749748011!
# > Validation Loss : 0.691338670881171!
#
# ******** Epoch [27/30]  ********
# Learning rate : 1.0000000000000002e-07
# Step 25/122 - mean loss : 0.36256808787584305
# Step 50/122 - mean loss : 0.36106574048801343
# Step 75/122 - mean loss : 0.3628258697084478
# Step 100/122 - mean loss : 0.3624436948636566
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-81555c9d9c29> in <module>
#      10
#      11   model.train() # training
# ---> 12   epoch_loss, _, _ = train_step(loader_train, model, criterion, optimizer, epoch)
#      13   losses_train += [epoch_loss]
#      14   print('> Training Loss : {epoch_loss}!'.format(epoch_loss=epoch_loss))
#
# <ipython-input-10-65b495b62387> in train_step(loader, model, criterion, optimizer, epoch)
#     145       optimizer.step()
#     146
# --> 147     epoch_loss_sum += [loss.item()]
#     148     predictions += [0]# [prediction]
#     149     labels += [0]#[label]
#
# KeyboardInterrupt:

# %% [markdown]
# # Compute loss on validation set
#
# Once the model is trained, the model is tested on the validation sample to calculate the mean and standard deviation of the losses, to see how well the model can generalise.

# %%
# load test loader witch batch size = 1
loader_val_loss = torch.utils.data.DataLoader(dataset_val, batch_size=1, shuffle=False)

# %%
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
losses_val = [] # lists to stock prediction, samples_id

for i, (data, label) in enumerate(loader_val_loss):
  # get input and sample
  data, label = data.to(device), label.to(device)

  # make prediction
  prediction = model(data)
  
  # get prediction and mask as numpy
  prediction = prediction[0][0].detach().cpu().numpy()
  possible_dose_mask = data[0][1].detach().cpu().numpy()
  # constraint mask to prediction
  new_prediction = prediction.copy()
  new_prediction[possible_dose_mask==0] = 0

  # compute loss
  label_np = label[0].detach().cpu().numpy()
  loss = criterion(torch.tensor(new_prediction), torch.tensor(label_np))
  losses_val.append(loss.item())

# %%
mean_loss, std_loss = np.mean(losses_val), np.std(losses_val)
print(f'Mean Loss : {mean_loss}')
print(f'Std Loss : {std_loss}')
# Out:
# Mean Loss : 0.6652674031102409
# Std Loss : 0.5355775260803896

# %% [markdown]
# # Prediction on test set
#
# Finally, prediction are made on the test set to get the score for the challenge.

# %%
# load test loader witch batch size = 1
loader_test = torch.utils.data.DataLoader(dataset_test, batch_size=1, shuffle=False)

# %%
# !rm -rf results

# %%
# Predictions on test set

# directory where results are saved
path_results = 'results/'
# create empty directory
if not os.path.exists(path_results):
  os.makedirs(path_results)

model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
predictions, samples_id = [], [] # lists to stock prediction, samples_id

for i, (data, sample_id) in enumerate(loader_test, 1):

  # get input and sample
  data, sample_id = data.to(device), list(sample_id)

  # make prediction
  prediction = model(data)
  
  # get prediction and mask as numpy
  prediction = prediction[0][0].detach().cpu().numpy()
  possible_dose_mask = data[0][1].detach().cpu().numpy()
  # constraint mask to prediction
  new_prediction = prediction.copy()
  new_prediction[possible_dose_mask==0] = 0

  # save predictions and samples
  predictions.append(new_prediction)
  samples_id += [sample_id[0]]

# list to array
predictions_array = np.array(predictions)

# save prediction as .npy file in 'results'
for pred, sample_id in zip(predictions_array, samples_id):
  path_to_save = os.path.join(path_results, sample_id + '.npy')
  np.save(path_to_save, pred)
  print(f'Sample {sample_id} prediction saved to {path_to_save} !')

# Folder as a zip and download it
shutil.make_archive('submission', 'zip', 'results/')
# Out:
# Sample sample_10067 prediction saved to results/sample_10067.npy !
# Sample sample_9180 prediction saved to results/sample_9180.npy !
# Sample sample_9851 prediction saved to results/sample_9851.npy !
# Sample sample_9415 prediction saved to results/sample_9415.npy !
# Sample sample_10058 prediction saved to results/sample_10058.npy !
# Sample sample_10137 prediction saved to results/sample_10137.npy !
# Sample sample_9099 prediction saved to results/sample_9099.npy !
# Sample sample_9594 prediction saved to results/sample_9594.npy !
# Sample sample_9722 prediction saved to results/sample_9722.npy !
# Sample sample_9019 prediction saved to results/sample_9019.npy !
# Sample sample_9147 prediction saved to results/sample_9147.npy !
# Sample sample_9113 prediction saved to results/sample_9113.npy !
# Sample sample_10056 prediction saved to results/sample_10056.npy !
# Sample sample_9052 prediction saved to results/sample_9052.npy !
# Sample sample_9387 prediction saved to results/sample_9387.npy !
# Sample sample_9066 prediction saved to results/sample_9066.npy !
# Sample sample_9082 prediction saved to results/sample_9082.npy !
# Sample sample_9409 prediction saved to results/sample_9409.npy !
# Sample sample_9222 prediction saved to results/sample_9222.npy !
# Sample sample_9324 prediction saved to results/sample_9324.npy !
# Sample sample_9985 prediction saved to results/sample_9985.npy !
# Sample sample_9553 prediction saved to results/sample_9553.npy !
# Sample sample_9752 prediction saved to results/sample_9752.npy !
# Sample sample_9421 prediction saved to results/sample_9421.npy !
# Sample sample_9088 prediction saved to results/sample_9088.npy !
# Sample sample_9829 prediction saved to results/sample_9829.npy !
# Sample sample_9018 prediction saved to results/sample_9018.npy !
# Sample sample_10149 prediction saved to results/sample_10149.npy !
# Sample sample_9531 prediction saved to results/sample_9531.npy !
# Sample sample_9623 prediction saved to results/sample_9623.npy !
# Sample sample_9708 prediction saved to results/sample_9708.npy !
# Sample sample_9341 prediction saved to results/sample_9341.npy !
# Sample sample_9960 prediction saved to results/sample_9960.npy !
# Sample sample_9513 prediction saved to results/sample_9513.npy !
# Sample sample_9343 prediction saved to results/sample_9343.npy !
# Sample sample_9149 prediction saved to results/sample_9149.npy !
# Sample sample_9697 prediction saved to results/sample_9697.npy !
# Sample sample_9624 prediction saved to results/sample_9624.npy !
# Sample sample_9287 prediction saved to results/sample_9287.npy !
# Sample sample_9669 prediction saved to results/sample_9669.npy !
# Sample sample_9023 prediction saved to results/sample_9023.npy !
# Sample sample_9970 prediction saved to results/sample_9970.npy !
# Sample sample_9700 prediction saved to results/sample_9700.npy !
# Sample sample_9982 prediction saved to results/sample_9982.npy !
# Sample sample_9711 prediction saved to results/sample_9711.npy !
# Sample sample_9164 prediction saved to results/sample_9164.npy !
# Sample sample_9798 prediction saved to results/sample_9798.npy !
# Sample sample_9973 prediction saved to results/sample_9973.npy !
# Sample sample_9045 prediction saved to results/sample_9045.npy !
# Sample sample_9130 prediction saved to results/sample_9130.npy !
# Sample sample_9772 prediction saved to results/sample_9772.npy !
# Sample sample_9350 prediction saved to results/sample_9350.npy !
# Sample sample_9073 prediction saved to results/sample_9073.npy !
# Sample sample_9092 prediction saved to results/sample_9092.npy !
# Sample sample_9992 prediction saved to results/sample_9992.npy !
# Sample sample_10032 prediction saved to results/sample_10032.npy !
# Sample sample_9814 prediction saved to results/sample_9814.npy !
# Sample sample_9537 prediction saved to results/sample_9537.npy !
# Sample sample_9467 prediction saved to results/sample_9467.npy !
# Sample sample_10074 prediction saved to results/sample_10074.npy !
# Sample sample_9949 prediction saved to results/sample_9949.npy !
# Sample sample_9579 prediction saved to results/sample_9579.npy !
# Sample sample_9795 prediction saved to results/sample_9795.npy !
# Sample sample_10148 prediction saved to results/sample_10148.npy !
# Sample sample_9385 prediction saved to results/sample_9385.npy !
# Sample sample_10084 prediction saved to results/sample_10084.npy !
# Sample sample_9759 prediction saved to results/sample_9759.npy !
# Sample sample_9418 prediction saved to results/sample_9418.npy !
# Sample sample_9370 prediction saved to results/sample_9370.npy !
# Sample sample_10027 prediction saved to results/sample_10027.npy !
# Sample sample_9800 prediction saved to results/sample_9800.npy !
# Sample sample_10152 prediction saved to results/sample_10152.npy !
# Sample sample_9248 prediction saved to results/sample_9248.npy !
# Sample sample_10150 prediction saved to results/sample_10150.npy !
# Sample sample_10049 prediction saved to results/sample_10049.npy !
# Sample sample_9431 prediction saved to results/sample_9431.npy !
# Sample sample_9854 prediction saved to results/sample_9854.npy !
# Sample sample_10130 prediction saved to results/sample_10130.npy !
# Sample sample_9530 prediction saved to results/sample_9530.npy !
# Sample sample_9670 prediction saved to results/sample_9670.npy !
# Sample sample_10050 prediction saved to results/sample_10050.npy !
# Sample sample_9304 prediction saved to results/sample_9304.npy !
# Sample sample_9986 prediction saved to results/sample_9986.npy !
# Sample sample_9381 prediction saved to results/sample_9381.npy !
# Sample sample_9549 prediction saved to results/sample_9549.npy !
# Sample sample_9258 prediction saved to results/sample_9258.npy !
# Sample sample_9644 prediction saved to results/sample_9644.npy !
# Sample sample_9246 prediction saved to results/sample_9246.npy !
# Sample sample_10195 prediction saved to results/sample_10195.npy !
# Sample sample_10011 prediction saved to results/sample_10011.npy !
# Sample sample_10012 prediction saved to results/sample_10012.npy !
# Sample sample_9619 prediction saved to results/sample_9619.npy !
# Sample sample_9348 prediction saved to results/sample_9348.npy !
# Sample sample_9557 prediction saved to results/sample_9557.npy !
# Sample sample_10172 prediction saved to results/sample_10172.npy !
# Sample sample_9819 prediction saved to results/sample_9819.npy !
# Sample sample_9902 prediction saved to results/sample_9902.npy !
# Sample sample_9270 prediction saved to results/sample_9270.npy !
# Sample sample_9501 prediction saved to results/sample_9501.npy !
# Sample sample_9165 prediction saved to results/sample_9165.npy !
# Sample sample_9159 prediction saved to results/sample_9159.npy !
# Sample sample_9733 prediction saved to results/sample_9733.npy !
# Sample sample_9373 prediction saved to results/sample_9373.npy !
# Sample sample_10088 prediction saved to results/sample_10088.npy !
# Sample sample_9021 prediction saved to results/sample_9021.npy !
# Sample sample_9606 prediction saved to results/sample_9606.npy !
# Sample sample_9036 prediction saved to results/sample_9036.npy !
# Sample sample_9574 prediction saved to results/sample_9574.npy !
# Sample sample_9299 prediction saved to results/sample_9299.npy !
# Sample sample_9009 prediction saved to results/sample_9009.npy !
# Sample sample_9556 prediction saved to results/sample_9556.npy !
# Sample sample_9332 prediction saved to results/sample_9332.npy !
# Sample sample_10185 prediction saved to results/sample_10185.npy !
# Sample sample_9952 prediction saved to results/sample_9952.npy !
# Sample sample_9463 prediction saved to results/sample_9463.npy !
# Sample sample_10168 prediction saved to results/sample_10168.npy !
# Sample sample_9310 prediction saved to results/sample_9310.npy !
# Sample sample_9481 prediction saved to results/sample_9481.npy !
# Sample sample_9461 prediction saved to results/sample_9461.npy !
# Sample sample_9524 prediction saved to results/sample_9524.npy !
# Sample sample_9730 prediction saved to results/sample_9730.npy !
# Sample sample_9737 prediction saved to results/sample_9737.npy !
# Sample sample_9281 prediction saved to results/sample_9281.npy !
# Sample sample_9641 prediction saved to results/sample_9641.npy !
# Sample sample_9305 prediction saved to results/sample_9305.npy !
# Sample sample_10076 prediction saved to results/sample_10076.npy !
# Sample sample_9826 prediction saved to results/sample_9826.npy !
# Sample sample_9895 prediction saved to results/sample_9895.npy !
# Sample sample_9870 prediction saved to results/sample_9870.npy !
# Sample sample_9806 prediction saved to results/sample_9806.npy !
# Sample sample_9361 prediction saved to results/sample_9361.npy !
# Sample sample_9406 prediction saved to results/sample_9406.npy !
# Sample sample_9578 prediction saved to results/sample_9578.npy !
# Sample sample_9646 prediction saved to results/sample_9646.npy !
# Sample sample_9634 prediction saved to results/sample_9634.npy !
# Sample sample_9358 prediction saved to results/sample_9358.npy !
# Sample sample_9529 prediction saved to results/sample_9529.npy !
# Sample sample_9401 prediction saved to results/sample_9401.npy !
# Sample sample_9515 prediction saved to results/sample_9515.npy !
# Sample sample_9108 prediction saved to results/sample_9108.npy !
# Sample sample_10072 prediction saved to results/sample_10072.npy !
# Sample sample_9618 prediction saved to results/sample_9618.npy !
# Sample sample_9844 prediction saved to results/sample_9844.npy !
# Sample sample_10021 prediction saved to results/sample_10021.npy !
# Sample sample_9469 prediction saved to results/sample_9469.npy !
# Sample sample_9145 prediction saved to results/sample_9145.npy !
# Sample sample_9822 prediction saved to results/sample_9822.npy !
# Sample sample_9871 prediction saved to results/sample_9871.npy !
# Sample sample_10054 prediction saved to results/sample_10054.npy !
# Sample sample_9761 prediction saved to results/sample_9761.npy !
# Sample sample_9975 prediction saved to results/sample_9975.npy !
# Sample sample_9077 prediction saved to results/sample_9077.npy !
# Sample sample_9947 prediction saved to results/sample_9947.npy !
# Sample sample_9868 prediction saved to results/sample_9868.npy !
# Sample sample_9091 prediction saved to results/sample_9091.npy !
# Sample sample_10124 prediction saved to results/sample_10124.npy !
# Sample sample_9220 prediction saved to results/sample_9220.npy !
# Sample sample_9607 prediction saved to results/sample_9607.npy !
# Sample sample_9176 prediction saved to results/sample_9176.npy !
# Sample sample_9990 prediction saved to results/sample_9990.npy !
# Sample sample_9999 prediction saved to results/sample_9999.npy !
# Sample sample_9677 prediction saved to results/sample_9677.npy !
# Sample sample_10044 prediction saved to results/sample_10044.npy !
# Sample sample_9849 prediction saved to results/sample_9849.npy !
# Sample sample_9047 prediction saved to results/sample_9047.npy !
# Sample sample_9153 prediction saved to results/sample_9153.npy !
# Sample sample_10002 prediction saved to results/sample_10002.npy !
# Sample sample_9137 prediction saved to results/sample_9137.npy !
# Sample sample_10029 prediction saved to results/sample_10029.npy !
# Sample sample_9559 prediction saved to results/sample_9559.npy !
# Sample sample_9692 prediction saved to results/sample_9692.npy !
# Sample sample_9441 prediction saved to results/sample_9441.npy !
# Sample sample_9878 prediction saved to results/sample_9878.npy !
# Sample sample_9277 prediction saved to results/sample_9277.npy !
# Sample sample_9213 prediction saved to results/sample_9213.npy !
# Sample sample_9156 prediction saved to results/sample_9156.npy !
# Sample sample_9779 prediction saved to results/sample_9779.npy !
# Sample sample_9909 prediction saved to results/sample_9909.npy !
# Sample sample_9253 prediction saved to results/sample_9253.npy !
# Sample sample_9209 prediction saved to results/sample_9209.npy !
# Sample sample_9944 prediction saved to results/sample_9944.npy !
# Sample sample_10039 prediction saved to results/sample_10039.npy !
# Sample sample_9765 prediction saved to results/sample_9765.npy !
# Sample sample_9821 prediction saved to results/sample_9821.npy !
# Sample sample_9100 prediction saved to results/sample_9100.npy !
# Sample sample_9166 prediction saved to results/sample_9166.npy !
# Sample sample_9676 prediction saved to results/sample_9676.npy !
# Sample sample_10040 prediction saved to results/sample_10040.npy !
# Sample sample_9775 prediction saved to results/sample_9775.npy !
# Sample sample_9249 prediction saved to results/sample_9249.npy !
# Sample sample_9771 prediction saved to results/sample_9771.npy !
# Sample sample_10114 prediction saved to results/sample_10114.npy !
# Sample sample_10105 prediction saved to results/sample_10105.npy !
# Sample sample_9141 prediction saved to results/sample_9141.npy !
# Sample sample_10144 prediction saved to results/sample_10144.npy !
# Sample sample_9943 prediction saved to results/sample_9943.npy !
# Sample sample_9923 prediction saved to results/sample_9923.npy !
# Sample sample_9230 prediction saved to results/sample_9230.npy !
# Sample sample_9521 prediction saved to results/sample_9521.npy !
# Sample sample_9456 prediction saved to results/sample_9456.npy !
# Sample sample_9595 prediction saved to results/sample_9595.npy !
# Sample sample_10151 prediction saved to results/sample_10151.npy !
# Sample sample_9823 prediction saved to results/sample_9823.npy !
# Sample sample_9705 prediction saved to results/sample_9705.npy !
# Sample sample_9502 prediction saved to results/sample_9502.npy !
# Sample sample_10019 prediction saved to results/sample_10019.npy !
# Sample sample_9500 prediction saved to results/sample_9500.npy !
# Sample sample_10080 prediction saved to results/sample_10080.npy !
# Sample sample_9425 prediction saved to results/sample_9425.npy !
# Sample sample_9175 prediction saved to results/sample_9175.npy !
# Sample sample_9398 prediction saved to results/sample_9398.npy !
# Sample sample_9323 prediction saved to results/sample_9323.npy !
# Sample sample_9184 prediction saved to results/sample_9184.npy !
# Sample sample_9319 prediction saved to results/sample_9319.npy !
# Sample sample_9451 prediction saved to results/sample_9451.npy !
# Sample sample_9412 prediction saved to results/sample_9412.npy !
# Sample sample_9792 prediction saved to results/sample_9792.npy !
# Sample sample_9653 prediction saved to results/sample_9653.npy !
# Sample sample_9022 prediction saved to results/sample_9022.npy !
# Sample sample_9678 prediction saved to results/sample_9678.npy !
# Sample sample_9017 prediction saved to results/sample_9017.npy !
# Sample sample_9562 prediction saved to results/sample_9562.npy !
# Sample sample_9079 prediction saved to results/sample_9079.npy !
# Sample sample_9447 prediction saved to results/sample_9447.npy !
# Sample sample_10140 prediction saved to results/sample_10140.npy !
# Sample sample_9919 prediction saved to results/sample_9919.npy !
# Sample sample_9437 prediction saved to results/sample_9437.npy !
# Sample sample_9912 prediction saved to results/sample_9912.npy !
# Sample sample_10104 prediction saved to results/sample_10104.npy !
# Sample sample_9811 prediction saved to results/sample_9811.npy !
# Sample sample_9025 prediction saved to results/sample_9025.npy !
# Sample sample_10022 prediction saved to results/sample_10022.npy !
# Sample sample_9691 prediction saved to results/sample_9691.npy !
# Sample sample_10178 prediction saved to results/sample_10178.npy !
# Sample sample_9859 prediction saved to results/sample_9859.npy !
# Sample sample_9093 prediction saved to results/sample_9093.npy !
# Sample sample_9107 prediction saved to results/sample_9107.npy !
# Sample sample_9635 prediction saved to results/sample_9635.npy !
# Sample sample_9762 prediction saved to results/sample_9762.npy !
# Sample sample_9377 prediction saved to results/sample_9377.npy !
# Sample sample_10095 prediction saved to results/sample_10095.npy !
# Sample sample_9015 prediction saved to results/sample_9015.npy !
# Sample sample_10141 prediction saved to results/sample_10141.npy !
# Sample sample_9268 prediction saved to results/sample_9268.npy !
# Sample sample_10111 prediction saved to results/sample_10111.npy !
# Sample sample_9728 prediction saved to results/sample_9728.npy !
# Sample sample_9114 prediction saved to results/sample_9114.npy !
# Sample sample_10068 prediction saved to results/sample_10068.npy !
# Sample sample_9550 prediction saved to results/sample_9550.npy !
# Sample sample_10157 prediction saved to results/sample_10157.npy !
# Sample sample_9648 prediction saved to results/sample_9648.npy !
# Sample sample_9707 prediction saved to results/sample_9707.npy !
# Sample sample_9203 prediction saved to results/sample_9203.npy !
# Sample sample_9339 prediction saved to results/sample_9339.npy !
# Sample sample_9236 prediction saved to results/sample_9236.npy !
# Sample sample_9288 prediction saved to results/sample_9288.npy !
# Sample sample_10187 prediction saved to results/sample_10187.npy !
# Sample sample_9187 prediction saved to results/sample_9187.npy !
# Sample sample_9984 prediction saved to results/sample_9984.npy !
# Sample sample_10006 prediction saved to results/sample_10006.npy !
# Sample sample_9150 prediction saved to results/sample_9150.npy !
# Sample sample_9893 prediction saved to results/sample_9893.npy !
# Sample sample_9780 prediction saved to results/sample_9780.npy !
# Sample sample_9581 prediction saved to results/sample_9581.npy !
# Sample sample_9924 prediction saved to results/sample_9924.npy !
# Sample sample_10134 prediction saved to results/sample_10134.npy !
# Sample sample_9979 prediction saved to results/sample_9979.npy !
# Sample sample_9428 prediction saved to results/sample_9428.npy !
# Sample sample_9300 prediction saved to results/sample_9300.npy !
# Sample sample_9466 prediction saved to results/sample_9466.npy !
# Sample sample_9954 prediction saved to results/sample_9954.npy !
# Sample sample_9284 prediction saved to results/sample_9284.npy !
# Sample sample_9948 prediction saved to results/sample_9948.npy !
# Sample sample_10007 prediction saved to results/sample_10007.npy !
# Sample sample_10173 prediction saved to results/sample_10173.npy !
# Sample sample_9886 prediction saved to results/sample_9886.npy !
# Sample sample_9356 prediction saved to results/sample_9356.npy !
# Sample sample_9262 prediction saved to results/sample_9262.npy !
# Sample sample_9450 prediction saved to results/sample_9450.npy !
# Sample sample_10120 prediction saved to results/sample_10120.npy !
# Sample sample_9497 prediction saved to results/sample_9497.npy !
# Sample sample_10101 prediction saved to results/sample_10101.npy !
# Sample sample_10028 prediction saved to results/sample_10028.npy !
# Sample sample_9389 prediction saved to results/sample_9389.npy !
# Sample sample_9560 prediction saved to results/sample_9560.npy !
# Sample sample_9492 prediction saved to results/sample_9492.npy !
# Sample sample_9138 prediction saved to results/sample_9138.npy !
# Sample sample_9534 prediction saved to results/sample_9534.npy !
# Sample sample_9051 prediction saved to results/sample_9051.npy !
# Sample sample_10174 prediction saved to results/sample_10174.npy !
# Sample sample_9351 prediction saved to results/sample_9351.npy !
# Sample sample_9334 prediction saved to results/sample_9334.npy !
# Sample sample_9063 prediction saved to results/sample_9063.npy !
# Sample sample_9512 prediction saved to results/sample_9512.npy !
# Sample sample_9462 prediction saved to results/sample_9462.npy !
# Sample sample_9071 prediction saved to results/sample_9071.npy !
# Sample sample_9802 prediction saved to results/sample_9802.npy !
# Sample sample_9122 prediction saved to results/sample_9122.npy !
# Sample sample_9265 prediction saved to results/sample_9265.npy !
# Sample sample_9916 prediction saved to results/sample_9916.npy !
# Sample sample_10061 prediction saved to results/sample_10061.npy !
# Sample sample_9588 prediction saved to results/sample_9588.npy !
# Sample sample_9330 prediction saved to results/sample_9330.npy !
# Sample sample_9572 prediction saved to results/sample_9572.npy !
# Sample sample_9129 prediction saved to results/sample_9129.npy !
# Sample sample_9815 prediction saved to results/sample_9815.npy !
# Sample sample_9379 prediction saved to results/sample_9379.npy !
# Sample sample_10118 prediction saved to results/sample_10118.npy !
# Sample sample_9154 prediction saved to results/sample_9154.npy !
# Sample sample_9701 prediction saved to results/sample_9701.npy !
# Sample sample_10034 prediction saved to results/sample_10034.npy !
# Sample sample_9509 prediction saved to results/sample_9509.npy !
# Sample sample_9846 prediction saved to results/sample_9846.npy !
# Sample sample_9053 prediction saved to results/sample_9053.npy !
# Sample sample_9928 prediction saved to results/sample_9928.npy !
# Sample sample_9235 prediction saved to results/sample_9235.npy !
# Sample sample_9650 prediction saved to results/sample_9650.npy !
# Sample sample_9519 prediction saved to results/sample_9519.npy !
# Sample sample_9097 prediction saved to results/sample_9097.npy !
# Sample sample_9062 prediction saved to results/sample_9062.npy !
# Sample sample_9983 prediction saved to results/sample_9983.npy !
# Sample sample_9331 prediction saved to results/sample_9331.npy !
# Sample sample_9715 prediction saved to results/sample_9715.npy !
# Sample sample_9085 prediction saved to results/sample_9085.npy !
# Sample sample_9732 prediction saved to results/sample_9732.npy !
# Sample sample_9132 prediction saved to results/sample_9132.npy !
# Sample sample_9060 prediction saved to results/sample_9060.npy !
# Sample sample_9423 prediction saved to results/sample_9423.npy !
# Sample sample_9491 prediction saved to results/sample_9491.npy !
# Sample sample_9666 prediction saved to results/sample_9666.npy !
# Sample sample_10017 prediction saved to results/sample_10017.npy !
# Sample sample_10070 prediction saved to results/sample_10070.npy !
# Sample sample_9186 prediction saved to results/sample_9186.npy !
# Sample sample_9971 prediction saved to results/sample_9971.npy !
# Sample sample_10023 prediction saved to results/sample_10023.npy !
# Sample sample_9987 prediction saved to results/sample_9987.npy !
# Sample sample_9640 prediction saved to results/sample_9640.npy !
# Sample sample_9344 prediction saved to results/sample_9344.npy !
# Sample sample_9414 prediction saved to results/sample_9414.npy !
# Sample sample_9232 prediction saved to results/sample_9232.npy !
# Sample sample_9297 prediction saved to results/sample_9297.npy !
# Sample sample_9485 prediction saved to results/sample_9485.npy !
# Sample sample_9078 prediction saved to results/sample_9078.npy !
# Sample sample_9755 prediction saved to results/sample_9755.npy !
# Sample sample_9188 prediction saved to results/sample_9188.npy !
# Sample sample_9197 prediction saved to results/sample_9197.npy !
# Sample sample_9504 prediction saved to results/sample_9504.npy !
# Sample sample_9476 prediction saved to results/sample_9476.npy !
# Sample sample_9498 prediction saved to results/sample_9498.npy !
# Sample sample_9189 prediction saved to results/sample_9189.npy !
# Sample sample_10191 prediction saved to results/sample_10191.npy !
# Sample sample_9696 prediction saved to results/sample_9696.npy !
# Sample sample_9254 prediction saved to results/sample_9254.npy !
# Sample sample_9855 prediction saved to results/sample_9855.npy !
# Sample sample_9496 prediction saved to results/sample_9496.npy !
# Sample sample_9816 prediction saved to results/sample_9816.npy !
# Sample sample_9605 prediction saved to results/sample_9605.npy !
# Sample sample_9869 prediction saved to results/sample_9869.npy !
# Sample sample_9604 prediction saved to results/sample_9604.npy !
# Sample sample_10193 prediction saved to results/sample_10193.npy !
# Sample sample_10190 prediction saved to results/sample_10190.npy !
# Sample sample_9684 prediction saved to results/sample_9684.npy !
# Sample sample_10145 prediction saved to results/sample_10145.npy !
# Sample sample_9734 prediction saved to results/sample_9734.npy !
# Sample sample_9477 prediction saved to results/sample_9477.npy !
# Sample sample_10057 prediction saved to results/sample_10057.npy !
# Sample sample_9256 prediction saved to results/sample_9256.npy !
# Sample sample_9567 prediction saved to results/sample_9567.npy !
# Sample sample_9767 prediction saved to results/sample_9767.npy !
# Sample sample_10083 prediction saved to results/sample_10083.npy !
# Sample sample_9117 prediction saved to results/sample_9117.npy !
# Sample sample_9239 prediction saved to results/sample_9239.npy !
# Sample sample_9904 prediction saved to results/sample_9904.npy !
# Sample sample_9251 prediction saved to results/sample_9251.npy !
# Sample sample_9490 prediction saved to results/sample_9490.npy !
# Sample sample_9794 prediction saved to results/sample_9794.npy !
# Sample sample_9820 prediction saved to results/sample_9820.npy !
# Sample sample_9289 prediction saved to results/sample_9289.npy !
# Sample sample_9907 prediction saved to results/sample_9907.npy !
# Sample sample_9689 prediction saved to results/sample_9689.npy !
# Sample sample_9885 prediction saved to results/sample_9885.npy !
# Sample sample_9585 prediction saved to results/sample_9585.npy !
# Sample sample_9224 prediction saved to results/sample_9224.npy !
# Sample sample_9170 prediction saved to results/sample_9170.npy !
# Sample sample_9900 prediction saved to results/sample_9900.npy !
# Sample sample_10063 prediction saved to results/sample_10063.npy !
# Sample sample_9325 prediction saved to results/sample_9325.npy !
# Sample sample_9168 prediction saved to results/sample_9168.npy !
# Sample sample_9416 prediction saved to results/sample_9416.npy !
# Sample sample_9911 prediction saved to results/sample_9911.npy !
# Sample sample_9589 prediction saved to results/sample_9589.npy !
# Sample sample_9558 prediction saved to results/sample_9558.npy !
# Sample sample_9058 prediction saved to results/sample_9058.npy !
# Sample sample_10167 prediction saved to results/sample_10167.npy !
# Sample sample_9639 prediction saved to results/sample_9639.npy !
# Sample sample_10121 prediction saved to results/sample_10121.npy !
# Sample sample_9135 prediction saved to results/sample_9135.npy !
# Sample sample_9038 prediction saved to results/sample_9038.npy !
# Sample sample_9205 prediction saved to results/sample_9205.npy !
# Sample sample_9014 prediction saved to results/sample_9014.npy !
# Sample sample_9231 prediction saved to results/sample_9231.npy !
# Sample sample_9899 prediction saved to results/sample_9899.npy !
# Sample sample_9041 prediction saved to results/sample_9041.npy !
# Sample sample_9240 prediction saved to results/sample_9240.npy !
# Sample sample_9283 prediction saved to results/sample_9283.npy !
# Sample sample_9044 prediction saved to results/sample_9044.npy !
# Sample sample_9395 prediction saved to results/sample_9395.npy !
# Sample sample_9742 prediction saved to results/sample_9742.npy !
# Sample sample_9897 prediction saved to results/sample_9897.npy !
# Sample sample_10153 prediction saved to results/sample_10153.npy !
# Sample sample_9303 prediction saved to results/sample_9303.npy !
# Sample sample_9958 prediction saved to results/sample_9958.npy !
# Sample sample_9043 prediction saved to results/sample_9043.npy !
# Sample sample_10183 prediction saved to results/sample_10183.npy !
# Sample sample_9861 prediction saved to results/sample_9861.npy !
# Sample sample_9453 prediction saved to results/sample_9453.npy !
# Sample sample_9843 prediction saved to results/sample_9843.npy !
# Sample sample_10042 prediction saved to results/sample_10042.npy !
# Sample sample_9727 prediction saved to results/sample_9727.npy !
# Sample sample_9879 prediction saved to results/sample_9879.npy !
# Sample sample_9059 prediction saved to results/sample_9059.npy !
# Sample sample_9369 prediction saved to results/sample_9369.npy !
# Sample sample_9245 prediction saved to results/sample_9245.npy !
# Sample sample_9776 prediction saved to results/sample_9776.npy !
# Sample sample_9190 prediction saved to results/sample_9190.npy !
# Sample sample_9738 prediction saved to results/sample_9738.npy !
# Sample sample_9848 prediction saved to results/sample_9848.npy !
# Sample sample_9438 prediction saved to results/sample_9438.npy !
# Sample sample_9704 prediction saved to results/sample_9704.npy !
# Sample sample_9961 prediction saved to results/sample_9961.npy !
# Sample sample_9101 prediction saved to results/sample_9101.npy !
# Sample sample_9862 prediction saved to results/sample_9862.npy !
# Sample sample_9793 prediction saved to results/sample_9793.npy !
# Sample sample_9546 prediction saved to results/sample_9546.npy !
# Sample sample_9445 prediction saved to results/sample_9445.npy !
# Sample sample_9809 prediction saved to results/sample_9809.npy !
# Sample sample_9922 prediction saved to results/sample_9922.npy !
# Sample sample_9528 prediction saved to results/sample_9528.npy !
# Sample sample_9926 prediction saved to results/sample_9926.npy !
# Sample sample_9298 prediction saved to results/sample_9298.npy !
# Sample sample_9383 prediction saved to results/sample_9383.npy !
# Sample sample_9243 prediction saved to results/sample_9243.npy !
# Sample sample_9789 prediction saved to results/sample_9789.npy !
# Sample sample_9432 prediction saved to results/sample_9432.npy !
# Sample sample_9322 prediction saved to results/sample_9322.npy !
# Sample sample_9482 prediction saved to results/sample_9482.npy !
# Sample sample_9185 prediction saved to results/sample_9185.npy !
# Sample sample_9719 prediction saved to results/sample_9719.npy !
# Sample sample_9125 prediction saved to results/sample_9125.npy !
# Sample sample_9576 prediction saved to results/sample_9576.npy !
# Sample sample_9191 prediction saved to results/sample_9191.npy !
# Sample sample_9338 prediction saved to results/sample_9338.npy !
# Sample sample_9087 prediction saved to results/sample_9087.npy !
# Sample sample_9436 prediction saved to results/sample_9436.npy !
# Sample sample_9988 prediction saved to results/sample_9988.npy !
# Sample sample_9662 prediction saved to results/sample_9662.npy !
# Sample sample_9621 prediction saved to results/sample_9621.npy !
# Sample sample_9229 prediction saved to results/sample_9229.npy !
# Sample sample_9875 prediction saved to results/sample_9875.npy !
# Sample sample_9564 prediction saved to results/sample_9564.npy !
# Sample sample_10198 prediction saved to results/sample_10198.npy !
# Sample sample_10053 prediction saved to results/sample_10053.npy !
# Sample sample_9032 prediction saved to results/sample_9032.npy !
# Sample sample_9452 prediction saved to results/sample_9452.npy !
# Sample sample_9533 prediction saved to results/sample_9533.npy !
# Sample sample_9028 prediction saved to results/sample_9028.npy !
# Sample sample_9552 prediction saved to results/sample_9552.npy !
# Sample sample_9575 prediction saved to results/sample_9575.npy !
# Sample sample_9647 prediction saved to results/sample_9647.npy !
# Sample sample_9012 prediction saved to results/sample_9012.npy !
# Sample sample_9290 prediction saved to results/sample_9290.npy !
# Sample sample_9237 prediction saved to results/sample_9237.npy !
# Sample sample_9835 prediction saved to results/sample_9835.npy !
# Sample sample_9008 prediction saved to results/sample_9008.npy !
# Sample sample_9548 prediction saved to results/sample_9548.npy !
# Sample sample_9294 prediction saved to results/sample_9294.npy !
# Sample sample_10154 prediction saved to results/sample_10154.npy !
# Sample sample_9179 prediction saved to results/sample_9179.npy !
# Sample sample_10108 prediction saved to results/sample_10108.npy !
# Sample sample_9840 prediction saved to results/sample_9840.npy !
# Sample sample_9291 prediction saved to results/sample_9291.npy !
# Sample sample_9306 prediction saved to results/sample_9306.npy !
# Sample sample_9563 prediction saved to results/sample_9563.npy !
# Sample sample_9914 prediction saved to results/sample_9914.npy !
# Sample sample_10125 prediction saved to results/sample_10125.npy !
# Sample sample_9889 prediction saved to results/sample_9889.npy !
# Sample sample_9720 prediction saved to results/sample_9720.npy !
# Sample sample_10024 prediction saved to results/sample_10024.npy !
# Sample sample_9430 prediction saved to results/sample_9430.npy !
# Sample sample_10188 prediction saved to results/sample_10188.npy !
# Sample sample_10045 prediction saved to results/sample_10045.npy !
# Sample sample_9444 prediction saved to results/sample_9444.npy !
# Sample sample_9539 prediction saved to results/sample_9539.npy !
# Sample sample_9805 prediction saved to results/sample_9805.npy !
# Sample sample_10113 prediction saved to results/sample_10113.npy !
# Sample sample_9040 prediction saved to results/sample_9040.npy !
# Sample sample_9850 prediction saved to results/sample_9850.npy !
# Sample sample_9643 prediction saved to results/sample_9643.npy !
# Sample sample_9399 prediction saved to results/sample_9399.npy !
# Sample sample_9367 prediction saved to results/sample_9367.npy !
# Sample sample_9873 prediction saved to results/sample_9873.npy !
# Sample sample_9405 prediction saved to results/sample_9405.npy !
# Sample sample_9743 prediction saved to results/sample_9743.npy !
# Sample sample_9852 prediction saved to results/sample_9852.npy !
# Sample sample_9378 prediction saved to results/sample_9378.npy !
# Sample sample_9993 prediction saved to results/sample_9993.npy !
# Sample sample_9454 prediction saved to results/sample_9454.npy !
# Sample sample_9788 prediction saved to results/sample_9788.npy !
# Sample sample_9813 prediction saved to results/sample_9813.npy !
# Sample sample_9934 prediction saved to results/sample_9934.npy !
# Sample sample_9105 prediction saved to results/sample_9105.npy !
# Sample sample_9747 prediction saved to results/sample_9747.npy !
# Sample sample_9413 prediction saved to results/sample_9413.npy !
# Sample sample_9799 prediction saved to results/sample_9799.npy !
# Sample sample_9996 prediction saved to results/sample_9996.npy !
# Sample sample_10166 prediction saved to results/sample_10166.npy !
# Sample sample_9223 prediction saved to results/sample_9223.npy !
# Sample sample_9837 prediction saved to results/sample_9837.npy !
# Sample sample_10109 prediction saved to results/sample_10109.npy !
# Sample sample_9090 prediction saved to results/sample_9090.npy !
# Sample sample_9234 prediction saved to results/sample_9234.npy !
# Sample sample_9033 prediction saved to results/sample_9033.npy !
# Sample sample_9831 prediction saved to results/sample_9831.npy !
# Sample sample_10189 prediction saved to results/sample_10189.npy !
# Sample sample_9661 prediction saved to results/sample_9661.npy !
# Sample sample_9726 prediction saved to results/sample_9726.npy !
# Sample sample_9442 prediction saved to results/sample_9442.npy !
# Sample sample_10186 prediction saved to results/sample_10186.npy !
# Sample sample_9551 prediction saved to results/sample_9551.npy !
# Sample sample_9724 prediction saved to results/sample_9724.npy !
# Sample sample_9174 prediction saved to results/sample_9174.npy !
# Sample sample_9592 prediction saved to results/sample_9592.npy !
# Sample sample_10162 prediction saved to results/sample_10162.npy !
# Sample sample_9584 prediction saved to results/sample_9584.npy !
# Sample sample_9269 prediction saved to results/sample_9269.npy !
# Sample sample_9968 prediction saved to results/sample_9968.npy !
# Sample sample_9626 prediction saved to results/sample_9626.npy !
# Sample sample_9652 prediction saved to results/sample_9652.npy !
# Sample sample_9178 prediction saved to results/sample_9178.npy !
# Sample sample_10000 prediction saved to results/sample_10000.npy !
# Sample sample_10060 prediction saved to results/sample_10060.npy !
# Sample sample_9376 prediction saved to results/sample_9376.npy !
# Sample sample_9037 prediction saved to results/sample_9037.npy !
# Sample sample_9583 prediction saved to results/sample_9583.npy !
# Sample sample_9419 prediction saved to results/sample_9419.npy !
# Sample sample_10087 prediction saved to results/sample_10087.npy !
# Sample sample_9660 prediction saved to results/sample_9660.npy !
# Sample sample_9569 prediction saved to results/sample_9569.npy !
# Sample sample_10075 prediction saved to results/sample_10075.npy !
# Sample sample_9709 prediction saved to results/sample_9709.npy !
# Sample sample_10069 prediction saved to results/sample_10069.npy !
# Sample sample_9292 prediction saved to results/sample_9292.npy !
# Sample sample_9808 prediction saved to results/sample_9808.npy !
# Sample sample_10016 prediction saved to results/sample_10016.npy !
# Sample sample_9642 prediction saved to results/sample_9642.npy !
# Sample sample_9888 prediction saved to results/sample_9888.npy !
# Sample sample_9797 prediction saved to results/sample_9797.npy !
# Sample sample_9487 prediction saved to results/sample_9487.npy !
# Sample sample_10133 prediction saved to results/sample_10133.npy !
# Sample sample_9459 prediction saved to results/sample_9459.npy !
# Sample sample_10036 prediction saved to results/sample_10036.npy !
# Sample sample_9842 prediction saved to results/sample_9842.npy !
# Sample sample_9532 prediction saved to results/sample_9532.npy !
# Sample sample_9002 prediction saved to results/sample_9002.npy !
# Sample sample_9657 prediction saved to results/sample_9657.npy !
# Sample sample_9110 prediction saved to results/sample_9110.npy !
# Sample sample_9273 prediction saved to results/sample_9273.npy !
# Sample sample_9966 prediction saved to results/sample_9966.npy !
# Sample sample_9903 prediction saved to results/sample_9903.npy !
# Sample sample_9279 prediction saved to results/sample_9279.npy !
# Sample sample_9959 prediction saved to results/sample_9959.npy !
# Sample sample_9478 prediction saved to results/sample_9478.npy !
# Sample sample_9217 prediction saved to results/sample_9217.npy !
# Sample sample_9526 prediction saved to results/sample_9526.npy !
# Sample sample_9774 prediction saved to results/sample_9774.npy !
# Sample sample_9111 prediction saved to results/sample_9111.npy !
# Sample sample_10197 prediction saved to results/sample_10197.npy !
# Sample sample_9094 prediction saved to results/sample_9094.npy !
# Sample sample_9587 prediction saved to results/sample_9587.npy !
# Sample sample_9163 prediction saved to results/sample_9163.npy !
# Sample sample_9404 prediction saved to results/sample_9404.npy !
# Sample sample_9636 prediction saved to results/sample_9636.npy !
# Sample sample_9543 prediction saved to results/sample_9543.npy !
# Sample sample_9259 prediction saved to results/sample_9259.npy !
# Sample sample_9699 prediction saved to results/sample_9699.npy !
# Sample sample_9863 prediction saved to results/sample_9863.npy !
# Sample sample_10127 prediction saved to results/sample_10127.npy !
# Sample sample_9242 prediction saved to results/sample_9242.npy !
# Sample sample_9340 prediction saved to results/sample_9340.npy !
# Sample sample_9199 prediction saved to results/sample_9199.npy !
# Sample sample_10119 prediction saved to results/sample_10119.npy !
# Sample sample_9391 prediction saved to results/sample_9391.npy !
# Sample sample_9981 prediction saved to results/sample_9981.npy !
# Sample sample_10143 prediction saved to results/sample_10143.npy !
# Sample sample_10131 prediction saved to results/sample_10131.npy !
# Sample sample_9392 prediction saved to results/sample_9392.npy !
# Sample sample_10169 prediction saved to results/sample_10169.npy !
# Sample sample_9363 prediction saved to results/sample_9363.npy !
# Sample sample_10092 prediction saved to results/sample_10092.npy !
# Sample sample_10031 prediction saved to results/sample_10031.npy !
# Sample sample_9403 prediction saved to results/sample_9403.npy !
# Sample sample_9267 prediction saved to results/sample_9267.npy !
# Sample sample_9731 prediction saved to results/sample_9731.npy !
# Sample sample_9610 prediction saved to results/sample_9610.npy !
# Sample sample_9118 prediction saved to results/sample_9118.npy !
# Sample sample_9286 prediction saved to results/sample_9286.npy !
# Sample sample_9282 prediction saved to results/sample_9282.npy !
# Sample sample_9882 prediction saved to results/sample_9882.npy !
# Sample sample_9276 prediction saved to results/sample_9276.npy !
# Sample sample_9599 prediction saved to results/sample_9599.npy !
# Sample sample_9207 prediction saved to results/sample_9207.npy !
# Sample sample_10180 prediction saved to results/sample_10180.npy !
# Sample sample_9622 prediction saved to results/sample_9622.npy !
# Sample sample_9084 prediction saved to results/sample_9084.npy !
# Sample sample_9967 prediction saved to results/sample_9967.npy !
# Sample sample_9547 prediction saved to results/sample_9547.npy !
# Sample sample_9717 prediction saved to results/sample_9717.npy !
# Sample sample_9372 prediction saved to results/sample_9372.npy !
# Sample sample_9710 prediction saved to results/sample_9710.npy !
# Sample sample_9329 prediction saved to results/sample_9329.npy !
# Sample sample_10199 prediction saved to results/sample_10199.npy !
# Sample sample_9590 prediction saved to results/sample_9590.npy !
# Sample sample_9659 prediction saved to results/sample_9659.npy !
# Sample sample_9474 prediction saved to results/sample_9474.npy !
# Sample sample_9827 prediction saved to results/sample_9827.npy !
# Sample sample_9729 prediction saved to results/sample_9729.npy !
# Sample sample_9086 prediction saved to results/sample_9086.npy !
# Sample sample_9915 prediction saved to results/sample_9915.npy !
# Sample sample_9541 prediction saved to results/sample_9541.npy !
# Sample sample_9807 prediction saved to results/sample_9807.npy !
# Sample sample_9301 prediction saved to results/sample_9301.npy !
# Sample sample_9102 prediction saved to results/sample_9102.npy !
# Sample sample_9616 prediction saved to results/sample_9616.npy !
# Sample sample_9686 prediction saved to results/sample_9686.npy !
# Sample sample_9003 prediction saved to results/sample_9003.npy !
# Sample sample_9202 prediction saved to results/sample_9202.npy !
# Sample sample_10025 prediction saved to results/sample_10025.npy !
# Sample sample_9255 prediction saved to results/sample_9255.npy !
# Sample sample_10090 prediction saved to results/sample_10090.npy !
# Sample sample_10099 prediction saved to results/sample_10099.npy !
# Sample sample_9612 prediction saved to results/sample_9612.npy !
# Sample sample_9371 prediction saved to results/sample_9371.npy !
# Sample sample_10110 prediction saved to results/sample_10110.npy !
# Sample sample_9503 prediction saved to results/sample_9503.npy !
# Sample sample_9196 prediction saved to results/sample_9196.npy !
# Sample sample_9388 prediction saved to results/sample_9388.npy !
# Sample sample_9151 prediction saved to results/sample_9151.npy !
# Sample sample_9570 prediction saved to results/sample_9570.npy !
# Sample sample_9278 prediction saved to results/sample_9278.npy !
# Sample sample_9573 prediction saved to results/sample_9573.npy !
# Sample sample_9366 prediction saved to results/sample_9366.npy !
# Sample sample_9219 prediction saved to results/sample_9219.npy !
# Sample sample_9681 prediction saved to results/sample_9681.npy !
# Sample sample_10171 prediction saved to results/sample_10171.npy !
# Sample sample_9046 prediction saved to results/sample_9046.npy !
# Sample sample_10008 prediction saved to results/sample_10008.npy !
# Sample sample_9285 prediction saved to results/sample_9285.npy !
# Sample sample_9796 prediction saved to results/sample_9796.npy !
# Sample sample_9160 prediction saved to results/sample_9160.npy !
# Sample sample_9942 prediction saved to results/sample_9942.npy !
# Sample sample_10048 prediction saved to results/sample_10048.npy !
# Sample sample_9420 prediction saved to results/sample_9420.npy !
# Sample sample_9744 prediction saved to results/sample_9744.npy !
# Sample sample_10122 prediction saved to results/sample_10122.npy !
# Sample sample_9359 prediction saved to results/sample_9359.npy !
# Sample sample_9408 prediction saved to results/sample_9408.npy !
# Sample sample_9115 prediction saved to results/sample_9115.npy !
# Sample sample_10001 prediction saved to results/sample_10001.npy !
# Sample sample_9271 prediction saved to results/sample_9271.npy !
# Sample sample_9208 prediction saved to results/sample_9208.npy !
# Sample sample_10192 prediction saved to results/sample_10192.npy !
# Sample sample_9148 prediction saved to results/sample_9148.npy !
# Sample sample_9672 prediction saved to results/sample_9672.npy !
# Sample sample_9471 prediction saved to results/sample_9471.npy !
# Sample sample_10115 prediction saved to results/sample_10115.npy !
# Sample sample_10135 prediction saved to results/sample_10135.npy !
# Sample sample_9777 prediction saved to results/sample_9777.npy !
# Sample sample_10155 prediction saved to results/sample_10155.npy !
# Sample sample_9940 prediction saved to results/sample_9940.npy !
# Sample sample_9517 prediction saved to results/sample_9517.npy !
# Sample sample_9627 prediction saved to results/sample_9627.npy !
# Sample sample_9608 prediction saved to results/sample_9608.npy !
# Sample sample_9980 prediction saved to results/sample_9980.npy !
# Sample sample_10102 prediction saved to results/sample_10102.npy !
# Sample sample_9803 prediction saved to results/sample_9803.npy !
# Sample sample_9200 prediction saved to results/sample_9200.npy !
# Sample sample_10077 prediction saved to results/sample_10077.npy !
# Sample sample_9335 prediction saved to results/sample_9335.npy !
# Sample sample_9458 prediction saved to results/sample_9458.npy !
# Sample sample_9554 prediction saved to results/sample_9554.npy !
# Sample sample_9930 prediction saved to results/sample_9930.npy !
# Sample sample_9321 prediction saved to results/sample_9321.npy !
# Sample sample_9127 prediction saved to results/sample_9127.npy !
# Sample sample_10004 prediction saved to results/sample_10004.npy !
# Sample sample_9384 prediction saved to results/sample_9384.npy !
# Sample sample_9753 prediction saved to results/sample_9753.npy !
# Sample sample_10041 prediction saved to results/sample_10041.npy !
# Sample sample_10132 prediction saved to results/sample_10132.npy !
# Sample sample_9314 prediction saved to results/sample_9314.npy !
# Sample sample_9435 prediction saved to results/sample_9435.npy !
# Sample sample_9629 prediction saved to results/sample_9629.npy !
# Sample sample_9007 prediction saved to results/sample_9007.npy !
# Sample sample_10052 prediction saved to results/sample_10052.npy !
# Sample sample_9337 prediction saved to results/sample_9337.npy !
# Sample sample_10073 prediction saved to results/sample_10073.npy !
# Sample sample_9713 prediction saved to results/sample_9713.npy !
# Sample sample_9756 prediction saved to results/sample_9756.npy !
# Sample sample_9171 prediction saved to results/sample_9171.npy !
# Sample sample_10128 prediction saved to results/sample_10128.npy !
# Sample sample_10156 prediction saved to results/sample_10156.npy !
# Sample sample_9516 prediction saved to results/sample_9516.npy !
# Sample sample_10136 prediction saved to results/sample_10136.npy !
# Sample sample_9480 prediction saved to results/sample_9480.npy !
# Sample sample_9402 prediction saved to results/sample_9402.npy !
# Sample sample_9716 prediction saved to results/sample_9716.npy !
# Sample sample_10093 prediction saved to results/sample_10093.npy !
# Sample sample_10170 prediction saved to results/sample_10170.npy !
# Sample sample_9144 prediction saved to results/sample_9144.npy !
# Sample sample_9834 prediction saved to results/sample_9834.npy !
# Sample sample_9880 prediction saved to results/sample_9880.npy !
# Sample sample_9881 prediction saved to results/sample_9881.npy !
# Sample sample_9183 prediction saved to results/sample_9183.npy !
# Sample sample_9201 prediction saved to results/sample_9201.npy !
# Sample sample_9057 prediction saved to results/sample_9057.npy !
# Sample sample_10165 prediction saved to results/sample_10165.npy !
# Sample sample_9296 prediction saved to results/sample_9296.npy !
# Sample sample_9434 prediction saved to results/sample_9434.npy !
# Sample sample_9479 prediction saved to results/sample_9479.npy !
# Sample sample_9654 prediction saved to results/sample_9654.npy !
# Sample sample_9411 prediction saved to results/sample_9411.npy !
# Sample sample_9832 prediction saved to results/sample_9832.npy !
# Sample sample_9050 prediction saved to results/sample_9050.npy !
# Sample sample_9525 prediction saved to results/sample_9525.npy !
# Sample sample_9143 prediction saved to results/sample_9143.npy !
# ...
# Sample sample_9468 prediction saved to results/sample_9468.npy !
# Sample sample_9342 prediction saved to results/sample_9342.npy !
# Sample sample_9906 prediction saved to results/sample_9906.npy !
# Sample sample_9443 prediction saved to results/sample_9443.npy !
# Sample sample_9825 prediction saved to results/sample_9825.npy !
# Sample sample_9991 prediction saved to results/sample_9991.npy !
# Sample sample_10106 prediction saved to results/sample_10106.npy !
# Sample sample_10046 prediction saved to results/sample_10046.npy !
# Sample sample_9598 prediction saved to results/sample_9598.npy !
# Sample sample_9568 prediction saved to results/sample_9568.npy !
# Sample sample_9739 prediction saved to results/sample_9739.npy !
# Sample sample_10020 prediction saved to results/sample_10020.npy !
# Sample sample_9860 prediction saved to results/sample_9860.npy !
# Sample sample_9866 prediction saved to results/sample_9866.npy !
# Sample sample_9596 prediction saved to results/sample_9596.npy !
# Sample sample_10010 prediction saved to results/sample_10010.npy !
# Sample sample_9671 prediction saved to results/sample_9671.npy !
# Sample sample_9177 prediction saved to results/sample_9177.npy !
# Sample sample_9830 prediction saved to results/sample_9830.npy !
# Sample sample_9972 prediction saved to results/sample_9972.npy !
# Sample sample_9275 prediction saved to results/sample_9275.npy !
# Sample sample_10177 prediction saved to results/sample_10177.npy !
# Sample sample_9465 prediction saved to results/sample_9465.npy !
# Sample sample_9693 prediction saved to results/sample_9693.npy !
# Sample sample_9770 prediction saved to results/sample_9770.npy !
# Sample sample_9508 prediction saved to results/sample_9508.npy !
# Sample sample_9953 prediction saved to results/sample_9953.npy !
# Sample sample_9280 prediction saved to results/sample_9280.npy !
# Sample sample_9758 prediction saved to results/sample_9758.npy !
# Sample sample_10091 prediction saved to results/sample_10091.npy !
# Sample sample_9582 prediction saved to results/sample_9582.npy !
# Sample sample_9706 prediction saved to results/sample_9706.npy !
# Sample sample_9974 prediction saved to results/sample_9974.npy !
# Sample sample_9152 prediction saved to results/sample_9152.npy !
# Sample sample_9140 prediction saved to results/sample_9140.npy !
# Sample sample_9139 prediction saved to results/sample_9139.npy !
# Sample sample_10196 prediction saved to results/sample_10196.npy !
# Sample sample_9804 prediction saved to results/sample_9804.npy !
# Sample sample_10179 prediction saved to results/sample_10179.npy !
# Sample sample_9054 prediction saved to results/sample_9054.npy !
# Sample sample_10138 prediction saved to results/sample_10138.npy !
# Sample sample_9680 prediction saved to results/sample_9680.npy !
# Sample sample_9355 prediction saved to results/sample_9355.npy !
# Sample sample_9908 prediction saved to results/sample_9908.npy !
# Sample sample_9167 prediction saved to results/sample_9167.npy !
# Sample sample_9527 prediction saved to results/sample_9527.npy !
# Sample sample_9193 prediction saved to results/sample_9193.npy !
# Sample sample_9394 prediction saved to results/sample_9394.npy !
# Sample sample_9630 prediction saved to results/sample_9630.npy !
# Sample sample_9493 prediction saved to results/sample_9493.npy !
# Sample sample_10096 prediction saved to results/sample_10096.npy !
# Sample sample_9545 prediction saved to results/sample_9545.npy !
# Sample sample_9864 prediction saved to results/sample_9864.npy !
# Sample sample_9455 prediction saved to results/sample_9455.npy !
# Sample sample_9757 prediction saved to results/sample_9757.npy !
# Sample sample_9081 prediction saved to results/sample_9081.npy !
# Sample sample_9001 prediction saved to results/sample_9001.npy !
# Sample sample_9935 prediction saved to results/sample_9935.npy !
# Sample sample_9195 prediction saved to results/sample_9195.npy !
# Sample sample_9357 prediction saved to results/sample_9357.npy !
# Sample sample_9061 prediction saved to results/sample_9061.npy !
# Sample sample_9613 prediction saved to results/sample_9613.npy !
# Sample sample_9089 prediction saved to results/sample_9089.npy !
# Sample sample_9658 prediction saved to results/sample_9658.npy !
# Sample sample_9951 prediction saved to results/sample_9951.npy !
# Sample sample_10082 prediction saved to results/sample_10082.npy !
# Sample sample_9941 prediction saved to results/sample_9941.npy !
# Sample sample_9067 prediction saved to results/sample_9067.npy !
# Sample sample_9264 prediction saved to results/sample_9264.npy !
# Sample sample_9679 prediction saved to results/sample_9679.npy !
# Sample sample_9393 prediction saved to results/sample_9393.npy !
# Sample sample_9749 prediction saved to results/sample_9749.npy !
# Sample sample_9274 prediction saved to results/sample_9274.npy !
# Sample sample_9211 prediction saved to results/sample_9211.npy !
# Sample sample_9989 prediction saved to results/sample_9989.npy !
# Sample sample_9833 prediction saved to results/sample_9833.npy !
# Sample sample_9920 prediction saved to results/sample_9920.npy !
# Sample sample_10175 prediction saved to results/sample_10175.npy !
# Sample sample_9065 prediction saved to results/sample_9065.npy !
# Sample sample_9836 prediction saved to results/sample_9836.npy !
# Sample sample_9241 prediction saved to results/sample_9241.npy !
# Sample sample_9810 prediction saved to results/sample_9810.npy !
# Sample sample_9853 prediction saved to results/sample_9853.npy !
# Sample sample_9682 prediction saved to results/sample_9682.npy !
# Sample sample_9134 prediction saved to results/sample_9134.npy !
# Sample sample_9440 prediction saved to results/sample_9440.npy !
# Sample sample_9773 prediction saved to results/sample_9773.npy !
# Sample sample_9746 prediction saved to results/sample_9746.npy !
# Sample sample_10089 prediction saved to results/sample_10089.npy !
# Sample sample_9121 prediction saved to results/sample_9121.npy !
# Sample sample_9544 prediction saved to results/sample_9544.npy !
# Sample sample_10043 prediction saved to results/sample_10043.npy !
# Sample sample_9801 prediction saved to results/sample_9801.npy !
# Sample sample_9347 prediction saved to results/sample_9347.npy !
# Sample sample_9116 prediction saved to results/sample_9116.npy !
# Sample sample_9128 prediction saved to results/sample_9128.npy !
# Sample sample_10003 prediction saved to results/sample_10003.npy !
# Sample sample_9027 prediction saved to results/sample_9027.npy !
# Sample sample_9778 prediction saved to results/sample_9778.npy !
# Sample sample_9824 prediction saved to results/sample_9824.npy !
# Sample sample_9898 prediction saved to results/sample_9898.npy !
# Sample sample_9016 prediction saved to results/sample_9016.npy !
# Sample sample_9080 prediction saved to results/sample_9080.npy !
# Sample sample_9703 prediction saved to results/sample_9703.npy !
# Sample sample_9856 prediction saved to results/sample_9856.npy !
# Sample sample_10066 prediction saved to results/sample_10066.npy !
# Sample sample_9768 prediction saved to results/sample_9768.npy !
# Sample sample_10035 prediction saved to results/sample_10035.npy !
# Sample sample_10009 prediction saved to results/sample_10009.npy !
# Sample sample_10018 prediction saved to results/sample_10018.npy !
# Sample sample_10033 prediction saved to results/sample_10033.npy !
# Sample sample_9938 prediction saved to results/sample_9938.npy !
# Sample sample_9410 prediction saved to results/sample_9410.npy !
# Sample sample_10159 prediction saved to results/sample_10159.npy !
# Sample sample_9031 prediction saved to results/sample_9031.npy !
# Sample sample_9494 prediction saved to results/sample_9494.npy !
# Sample sample_9905 prediction saved to results/sample_9905.npy !
# Sample sample_9714 prediction saved to results/sample_9714.npy !
# Sample sample_10037 prediction saved to results/sample_10037.npy !
# Sample sample_9312 prediction saved to results/sample_9312.npy !
# Sample sample_9039 prediction saved to results/sample_9039.npy !
# Sample sample_9029 prediction saved to results/sample_9029.npy !
# Sample sample_9896 prediction saved to results/sample_9896.npy !
# Sample sample_9126 prediction saved to results/sample_9126.npy !
# Sample sample_9173 prediction saved to results/sample_9173.npy !
# Sample sample_9917 prediction saved to results/sample_9917.npy !
# Sample sample_9417 prediction saved to results/sample_9417.npy !
# Sample sample_9227 prediction saved to results/sample_9227.npy !
# Sample sample_9104 prediction saved to results/sample_9104.npy !
# Sample sample_9812 prediction saved to results/sample_9812.npy !
# Sample sample_9664 prediction saved to results/sample_9664.npy !
# Sample sample_10097 prediction saved to results/sample_10097.npy !
# Sample sample_9244 prediction saved to results/sample_9244.npy !
# Sample sample_9913 prediction saved to results/sample_9913.npy !
# Sample sample_9507 prediction saved to results/sample_9507.npy !
# Sample sample_9318 prediction saved to results/sample_9318.npy !
# Sample sample_9818 prediction saved to results/sample_9818.npy !
# Sample sample_9955 prediction saved to results/sample_9955.npy !
# Sample sample_9874 prediction saved to results/sample_9874.npy !
# Sample sample_9631 prediction saved to results/sample_9631.npy !
# Sample sample_9925 prediction saved to results/sample_9925.npy !
# Sample sample_10194 prediction saved to results/sample_10194.npy !
# Sample sample_9400 prediction saved to results/sample_9400.npy !
# Sample sample_9725 prediction saved to results/sample_9725.npy !
# Sample sample_9133 prediction saved to results/sample_9133.npy !
# Sample sample_9969 prediction saved to results/sample_9969.npy !
# Sample sample_9877 prediction saved to results/sample_9877.npy !
# Sample sample_9764 prediction saved to results/sample_9764.npy !
# Sample sample_9828 prediction saved to results/sample_9828.npy !
# Sample sample_9510 prediction saved to results/sample_9510.npy !
# Sample sample_9210 prediction saved to results/sample_9210.npy !
# Sample sample_9591 prediction saved to results/sample_9591.npy !
# Sample sample_9011 prediction saved to results/sample_9011.npy !
# Sample sample_9784 prediction saved to results/sample_9784.npy !
# Sample sample_9396 prediction saved to results/sample_9396.npy !
# Sample sample_9748 prediction saved to results/sample_9748.npy !
# Sample sample_9655 prediction saved to results/sample_9655.npy !
# Sample sample_9375 prediction saved to results/sample_9375.npy !
# Sample sample_9977 prediction saved to results/sample_9977.npy !
# Sample sample_9345 prediction saved to results/sample_9345.npy !
# Sample sample_9964 prediction saved to results/sample_9964.npy !
# Sample sample_10164 prediction saved to results/sample_10164.npy !
# Sample sample_10079 prediction saved to results/sample_10079.npy !
# Sample sample_9702 prediction saved to results/sample_9702.npy !
# Sample sample_9181 prediction saved to results/sample_9181.npy !
# Sample sample_9169 prediction saved to results/sample_9169.npy !
# Sample sample_10147 prediction saved to results/sample_10147.npy !
# Sample sample_9736 prediction saved to results/sample_9736.npy !
# Sample sample_9740 prediction saved to results/sample_9740.npy !
# Sample sample_9315 prediction saved to results/sample_9315.npy !
# Sample sample_9994 prediction saved to results/sample_9994.npy !
# Sample sample_10107 prediction saved to results/sample_10107.npy !
# Sample sample_9872 prediction saved to results/sample_9872.npy !
# Sample sample_9068 prediction saved to results/sample_9068.npy !
# Sample sample_9360 prediction saved to results/sample_9360.npy !
# Sample sample_9901 prediction saved to results/sample_9901.npy !
# Sample sample_9763 prediction saved to results/sample_9763.npy !
# Sample sample_9470 prediction saved to results/sample_9470.npy !
# Sample sample_9390 prediction saved to results/sample_9390.npy !
# Sample sample_9673 prediction saved to results/sample_9673.npy !
# Sample sample_9433 prediction saved to results/sample_9433.npy !
# Sample sample_9233 prediction saved to results/sample_9233.npy !
# Sample sample_9293 prediction saved to results/sample_9293.npy !
# Sample sample_9035 prediction saved to results/sample_9035.npy !
# Sample sample_9096 prediction saved to results/sample_9096.npy !
# Sample sample_9257 prediction saved to results/sample_9257.npy !
# Sample sample_9460 prediction saved to results/sample_9460.npy !
# Sample sample_9633 prediction saved to results/sample_9633.npy !
# Sample sample_9439 prediction saved to results/sample_9439.npy !
# Sample sample_9995 prediction saved to results/sample_9995.npy !
# Sample sample_10005 prediction saved to results/sample_10005.npy !
# Sample sample_9600 prediction saved to results/sample_9600.npy !
# Sample sample_9076 prediction saved to results/sample_9076.npy !
# Sample sample_9112 prediction saved to results/sample_9112.npy !
# Sample sample_9124 prediction saved to results/sample_9124.npy !
# Sample sample_9010 prediction saved to results/sample_9010.npy !
# Sample sample_9382 prediction saved to results/sample_9382.npy !
# Sample sample_10176 prediction saved to results/sample_10176.npy !
# Sample sample_9449 prediction saved to results/sample_9449.npy !
# Sample sample_9475 prediction saved to results/sample_9475.npy !
# Sample sample_9075 prediction saved to results/sample_9075.npy !
# Sample sample_9847 prediction saved to results/sample_9847.npy !
# Sample sample_9030 prediction saved to results/sample_9030.npy !
# Sample sample_9427 prediction saved to results/sample_9427.npy !
# Sample sample_9311 prediction saved to results/sample_9311.npy !
# Sample sample_10163 prediction saved to results/sample_10163.npy !
# Sample sample_9963 prediction saved to results/sample_9963.npy !
# Sample sample_9933 prediction saved to results/sample_9933.npy !
# Sample sample_9204 prediction saved to results/sample_9204.npy !
# Sample sample_9448 prediction saved to results/sample_9448.npy !
# Sample sample_9386 prediction saved to results/sample_9386.npy !
# Sample sample_9523 prediction saved to results/sample_9523.npy !
# Sample sample_9745 prediction saved to results/sample_9745.npy !
# Sample sample_9611 prediction saved to results/sample_9611.npy !
# Sample sample_9429 prediction saved to results/sample_9429.npy !
# Sample sample_9307 prediction saved to results/sample_9307.npy !
# Sample sample_9212 prediction saved to results/sample_9212.npy !
# Sample sample_9198 prediction saved to results/sample_9198.npy !
# Sample sample_9956 prediction saved to results/sample_9956.npy !
# Sample sample_9751 prediction saved to results/sample_9751.npy !
# Sample sample_9328 prediction saved to results/sample_9328.npy !
# Sample sample_9505 prediction saved to results/sample_9505.npy !
# Sample sample_9261 prediction saved to results/sample_9261.npy !
# Sample sample_9272 prediction saved to results/sample_9272.npy !
# Sample sample_9042 prediction saved to results/sample_9042.npy !
# Sample sample_9353 prediction saved to results/sample_9353.npy !
# Sample sample_9333 prediction saved to results/sample_9333.npy !
# Sample sample_9674 prediction saved to results/sample_9674.npy !
# Sample sample_9226 prediction saved to results/sample_9226.npy !
# Sample sample_9473 prediction saved to results/sample_9473.npy !
# Sample sample_9489 prediction saved to results/sample_9489.npy !
# Sample sample_10123 prediction saved to results/sample_10123.npy !
# Sample sample_9741 prediction saved to results/sample_9741.npy !
# Sample sample_9308 prediction saved to results/sample_9308.npy !
# Sample sample_9976 prediction saved to results/sample_9976.npy !
# Sample sample_9876 prediction saved to results/sample_9876.npy !
# Sample sample_9891 prediction saved to results/sample_9891.npy !
# Sample sample_9667 prediction saved to results/sample_9667.npy !
# Sample sample_9617 prediction saved to results/sample_9617.npy !
# Sample sample_9791 prediction saved to results/sample_9791.npy !
# Sample sample_9422 prediction saved to results/sample_9422.npy !
# Sample sample_9918 prediction saved to results/sample_9918.npy !
# Sample sample_9838 prediction saved to results/sample_9838.npy !
# Sample sample_10103 prediction saved to results/sample_10103.npy !
# '/content/submission.zip'

# %% [markdown]
# # Qualitative results

# %%
labels = []
predictions = []
model.eval()
for i, (data, label) in enumerate(loader_val_loss):
  # get input and sample
  data, label = data.to(device), label.to(device)

  # make prediction
  prediction = model(data)
  
  # get prediction and mask as numpy
  prediction = prediction[0][0].detach().cpu().numpy()
  possible_dose_mask = data[0][1].detach().cpu().numpy()
  # constraint mask to prediction
  new_prediction = prediction.copy()
  new_prediction[possible_dose_mask==0] = 0
  
  labels.append(label.detach().cpu().numpy()[0])
  predictions.append(new_prediction)

# %%
# select idx of validation sample to display
idx = 25
img_label = labels[idx]
img_prediction = predictions[idx]

print(f'Loss : {criterion(torch.tensor(img_prediction), torch.tensor(img_label)).item()}')

# label
plt.imshow(img_label)
plt.axis('off')
plt.savefig(f'label_{idx}.png', bbox_inches='tight')
plt.show()

# prediction
plt.imshow(img_prediction)
plt.axis('off')
plt.savefig(f'predictions_{idx}.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # END of the notebook !
#
# Thank you for reading !
